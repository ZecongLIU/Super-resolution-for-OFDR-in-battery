# %%
# 剪取视频截图
import cv2
import os

# 视频文件路径
video_path = r'D:\Program\d2l\battery\10.11ce\20241011_110212.mp4'

# 生成指定的截取时间点（从0秒开始，每4秒取一个，共取144个）
start_time = 0
interval = 4
num_frames = 35

time_points = [start_time + i * interval for i in range(num_frames)]

# 输出文件夹
output_folder = 'extracted_frames'
os.makedirs(output_folder, exist_ok=True)

# 加载视频
cap = cv2.VideoCapture(video_path)

# 获取视频的帧率
fps = cap.get(cv2.CAP_PROP_FPS)
print(f"视频的帧率为: {fps} fps")

# 遍历指定的时间点
for idx, t in enumerate(time_points):
    # 计算需要跳转的帧数
    frame_id = int(fps * t)
    # 设置视频的位置
    cap.set(cv2.CAP_PROP_POS_FRAMES, frame_id)
    # 读取帧
    ret, frame = cap.read()
    if ret:
        # 构建保存帧的文件路径，名称排序为 76-220
        frame_filename = f'frame_{idx + 220}.jpg'
        frame_path = os.path.join(output_folder, frame_filename)
        # 保存截取的帧到指定文件夹
        cv2.imwrite(frame_path, frame)
        print(f"已保存帧：{frame_path}")
    else:
        print(f"无法读取第 {t} 秒的帧。")

# 释放视频对象
cap.release()
print('所有截图已完成。')
# Out:
# 视频的帧率为: 50.0 fps
# 已保存帧：extracted_frames\frame_220.jpg
# 已保存帧：extracted_frames\frame_221.jpg
# 已保存帧：extracted_frames\frame_222.jpg
# 已保存帧：extracted_frames\frame_223.jpg
# 已保存帧：extracted_frames\frame_224.jpg
# 已保存帧：extracted_frames\frame_225.jpg
# 已保存帧：extracted_frames\frame_226.jpg
# 已保存帧：extracted_frames\frame_227.jpg
# 已保存帧：extracted_frames\frame_228.jpg
# 已保存帧：extracted_frames\frame_229.jpg
# 已保存帧：extracted_frames\frame_230.jpg
# 已保存帧：extracted_frames\frame_231.jpg
# 已保存帧：extracted_frames\frame_232.jpg
# 已保存帧：extracted_frames\frame_233.jpg
# 已保存帧：extracted_frames\frame_234.jpg
# 已保存帧：extracted_frames\frame_235.jpg
# 已保存帧：extracted_frames\frame_236.jpg
# 已保存帧：extracted_frames\frame_237.jpg
# 已保存帧：extracted_frames\frame_238.jpg
# 已保存帧：extracted_frames\frame_239.jpg
# 已保存帧：extracted_frames\frame_240.jpg
# 已保存帧：extracted_frames\frame_241.jpg
# 已保存帧：extracted_frames\frame_242.jpg
# 已保存帧：extracted_frames\frame_243.jpg
# 已保存帧：extracted_frames\frame_244.jpg
# 已保存帧：extracted_frames\frame_245.jpg
# 已保存帧：extracted_frames\frame_246.jpg
# 已保存帧：extracted_frames\frame_247.jpg
# 已保存帧：extracted_frames\frame_248.jpg
# 已保存帧：extracted_frames\frame_249.jpg
# 已保存帧：extracted_frames\frame_250.jpg
# 已保存帧：extracted_frames\frame_251.jpg
# 已保存帧：extracted_frames\frame_252.jpg
# 已保存帧：extracted_frames\frame_253.jpg
# 已保存帧：extracted_frames\frame_254.jpg
# 所有截图已完成。

# %%
# 裁剪截图
import cv2
import glob
import os

# 定义裁剪区域的坐标
x = 146  # 从左到右的像素位置
y = 108  # 从上到下的像素位置
w = 260  # 裁剪区域的宽度
h = 260  # 裁剪区域的高度

# 创建保存裁剪后图像的文件夹
output_folder = 'cropped_frames'
os.makedirs(output_folder, exist_ok=True)

# 获取所有截取的帧图像文件名，并按文件名排序
image_files = sorted(glob.glob('extracted_frames\\frame_*.jpg'), key=lambda x: int(os.path.basename(x).split('_')[1].split('.')[0]))

for img_file in image_files:
    # 读取图像
    image = cv2.imread(img_file)
    if image is None:
        print(f"无法读取图像文件：{img_file}")
        continue

    # 获取图像的尺寸
    height, width = image.shape[:2]
    print(f"正在处理图像：{img_file}，尺寸为：{width}x{height}")

    # 检查裁剪区域是否超出图像范围
    if x + w > width or y + h > height:
        print(f"图像 {img_file} 的裁剪区域超出范围，已跳过。")
        continue

    # 裁剪图像
    cropped_image = image[y:y+h, x:x+w]

    # 保持裁剪后文件名与原文件名完全一致，但保存到新的文件夹中
    cropped_filename = os.path.join(output_folder, os.path.basename(img_file))

    # 保存裁剪后的图像
    success = cv2.imwrite(cropped_filename, cropped_image)
    if success:
        print(f"已保存裁剪后的图像：{cropped_filename}，成功！")
    else:
        print(f"保存裁剪后的图像失败：{cropped_filename}")

print('所有图像裁剪已完成。')
# Out:
# 正在处理图像：extracted_frames\frame_1.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_1.jpg，成功！
# 正在处理图像：extracted_frames\frame_2.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_2.jpg，成功！
# 正在处理图像：extracted_frames\frame_3.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_3.jpg，成功！
# 正在处理图像：extracted_frames\frame_4.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_4.jpg，成功！
# 正在处理图像：extracted_frames\frame_5.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_5.jpg，成功！
# 正在处理图像：extracted_frames\frame_6.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_6.jpg，成功！
# 正在处理图像：extracted_frames\frame_7.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_7.jpg，成功！
# 正在处理图像：extracted_frames\frame_8.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_8.jpg，成功！
# 正在处理图像：extracted_frames\frame_9.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_9.jpg，成功！
# 正在处理图像：extracted_frames\frame_10.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_10.jpg，成功！
# 正在处理图像：extracted_frames\frame_11.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_11.jpg，成功！
# 正在处理图像：extracted_frames\frame_12.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_12.jpg，成功！
# 正在处理图像：extracted_frames\frame_13.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_13.jpg，成功！
# 正在处理图像：extracted_frames\frame_14.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_14.jpg，成功！
# 正在处理图像：extracted_frames\frame_15.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_15.jpg，成功！
# 正在处理图像：extracted_frames\frame_16.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_16.jpg，成功！
# 正在处理图像：extracted_frames\frame_17.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_17.jpg，成功！
# 正在处理图像：extracted_frames\frame_18.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_18.jpg，成功！
# 正在处理图像：extracted_frames\frame_19.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_19.jpg，成功！
# 正在处理图像：extracted_frames\frame_20.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_20.jpg，成功！
# 正在处理图像：extracted_frames\frame_21.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_21.jpg，成功！
# 正在处理图像：extracted_frames\frame_22.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_22.jpg，成功！
# 正在处理图像：extracted_frames\frame_23.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_23.jpg，成功！
# 正在处理图像：extracted_frames\frame_24.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_24.jpg，成功！
# 正在处理图像：extracted_frames\frame_25.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_25.jpg，成功！
# 正在处理图像：extracted_frames\frame_26.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_26.jpg，成功！
# 正在处理图像：extracted_frames\frame_27.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_27.jpg，成功！
# 正在处理图像：extracted_frames\frame_28.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_28.jpg，成功！
# 正在处理图像：extracted_frames\frame_29.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_29.jpg，成功！
# 正在处理图像：extracted_frames\frame_30.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_30.jpg，成功！
# 正在处理图像：extracted_frames\frame_31.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_31.jpg，成功！
# 正在处理图像：extracted_frames\frame_32.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_32.jpg，成功！
# 正在处理图像：extracted_frames\frame_33.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_33.jpg，成功！
# 正在处理图像：extracted_frames\frame_34.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_34.jpg，成功！
# 正在处理图像：extracted_frames\frame_35.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_35.jpg，成功！
# 正在处理图像：extracted_frames\frame_36.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_36.jpg，成功！
# 正在处理图像：extracted_frames\frame_37.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_37.jpg，成功！
# 正在处理图像：extracted_frames\frame_38.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_38.jpg，成功！
# 正在处理图像：extracted_frames\frame_39.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_39.jpg，成功！
# 正在处理图像：extracted_frames\frame_40.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_40.jpg，成功！
# 正在处理图像：extracted_frames\frame_41.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_41.jpg，成功！
# 正在处理图像：extracted_frames\frame_42.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_42.jpg，成功！
# 正在处理图像：extracted_frames\frame_43.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_43.jpg，成功！
# 正在处理图像：extracted_frames\frame_44.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_44.jpg，成功！
# 正在处理图像：extracted_frames\frame_45.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_45.jpg，成功！
# 正在处理图像：extracted_frames\frame_46.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_46.jpg，成功！
# 正在处理图像：extracted_frames\frame_47.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_47.jpg，成功！
# 正在处理图像：extracted_frames\frame_48.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_48.jpg，成功！
# 正在处理图像：extracted_frames\frame_49.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_49.jpg，成功！
# 正在处理图像：extracted_frames\frame_50.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_50.jpg，成功！
# 正在处理图像：extracted_frames\frame_51.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_51.jpg，成功！
# 正在处理图像：extracted_frames\frame_52.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_52.jpg，成功！
# 正在处理图像：extracted_frames\frame_53.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_53.jpg，成功！
# 正在处理图像：extracted_frames\frame_54.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_54.jpg，成功！
# 正在处理图像：extracted_frames\frame_55.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_55.jpg，成功！
# 正在处理图像：extracted_frames\frame_56.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_56.jpg，成功！
# 正在处理图像：extracted_frames\frame_57.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_57.jpg，成功！
# 正在处理图像：extracted_frames\frame_58.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_58.jpg，成功！
# 正在处理图像：extracted_frames\frame_59.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_59.jpg，成功！
# 正在处理图像：extracted_frames\frame_60.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_60.jpg，成功！
# 正在处理图像：extracted_frames\frame_61.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_61.jpg，成功！
# 正在处理图像：extracted_frames\frame_62.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_62.jpg，成功！
# 正在处理图像：extracted_frames\frame_63.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_63.jpg，成功！
# 正在处理图像：extracted_frames\frame_64.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_64.jpg，成功！
# 正在处理图像：extracted_frames\frame_65.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_65.jpg，成功！
# 正在处理图像：extracted_frames\frame_66.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_66.jpg，成功！
# 正在处理图像：extracted_frames\frame_67.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_67.jpg，成功！
# 正在处理图像：extracted_frames\frame_68.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_68.jpg，成功！
# 正在处理图像：extracted_frames\frame_69.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_69.jpg，成功！
# 正在处理图像：extracted_frames\frame_70.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_70.jpg，成功！
# 正在处理图像：extracted_frames\frame_71.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_71.jpg，成功！
# 正在处理图像：extracted_frames\frame_72.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_72.jpg，成功！
# 正在处理图像：extracted_frames\frame_73.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_73.jpg，成功！
# 正在处理图像：extracted_frames\frame_74.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_74.jpg，成功！
# 正在处理图像：extracted_frames\frame_75.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_75.jpg，成功！
# 正在处理图像：extracted_frames\frame_76.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_76.jpg，成功！
# 正在处理图像：extracted_frames\frame_77.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_77.jpg，成功！
# 正在处理图像：extracted_frames\frame_78.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_78.jpg，成功！
# 正在处理图像：extracted_frames\frame_79.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_79.jpg，成功！
# 正在处理图像：extracted_frames\frame_80.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_80.jpg，成功！
# 正在处理图像：extracted_frames\frame_81.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_81.jpg，成功！
# 正在处理图像：extracted_frames\frame_82.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_82.jpg，成功！
# 正在处理图像：extracted_frames\frame_83.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_83.jpg，成功！
# 正在处理图像：extracted_frames\frame_84.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_84.jpg，成功！
# 正在处理图像：extracted_frames\frame_85.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_85.jpg，成功！
# 正在处理图像：extracted_frames\frame_86.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_86.jpg，成功！
# 正在处理图像：extracted_frames\frame_87.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_87.jpg，成功！
# 正在处理图像：extracted_frames\frame_88.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_88.jpg，成功！
# 正在处理图像：extracted_frames\frame_89.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_89.jpg，成功！
# 正在处理图像：extracted_frames\frame_90.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_90.jpg，成功！
# 正在处理图像：extracted_frames\frame_91.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_91.jpg，成功！
# 正在处理图像：extracted_frames\frame_92.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_92.jpg，成功！
# 正在处理图像：extracted_frames\frame_93.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_93.jpg，成功！
# 正在处理图像：extracted_frames\frame_94.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_94.jpg，成功！
# 正在处理图像：extracted_frames\frame_95.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_95.jpg，成功！
# 正在处理图像：extracted_frames\frame_96.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_96.jpg，成功！
# 正在处理图像：extracted_frames\frame_97.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_97.jpg，成功！
# 正在处理图像：extracted_frames\frame_98.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_98.jpg，成功！
# 正在处理图像：extracted_frames\frame_99.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_99.jpg，成功！
# 正在处理图像：extracted_frames\frame_100.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_100.jpg，成功！
# 正在处理图像：extracted_frames\frame_101.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_101.jpg，成功！
# 正在处理图像：extracted_frames\frame_102.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_102.jpg，成功！
# 正在处理图像：extracted_frames\frame_103.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_103.jpg，成功！
# 正在处理图像：extracted_frames\frame_104.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_104.jpg，成功！
# 正在处理图像：extracted_frames\frame_105.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_105.jpg，成功！
# 正在处理图像：extracted_frames\frame_106.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_106.jpg，成功！
# 正在处理图像：extracted_frames\frame_107.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_107.jpg，成功！
# 正在处理图像：extracted_frames\frame_108.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_108.jpg，成功！
# 正在处理图像：extracted_frames\frame_109.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_109.jpg，成功！
# 正在处理图像：extracted_frames\frame_110.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_110.jpg，成功！
# 正在处理图像：extracted_frames\frame_111.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_111.jpg，成功！
# 正在处理图像：extracted_frames\frame_112.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_112.jpg，成功！
# 正在处理图像：extracted_frames\frame_113.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_113.jpg，成功！
# 正在处理图像：extracted_frames\frame_114.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_114.jpg，成功！
# 正在处理图像：extracted_frames\frame_115.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_115.jpg，成功！
# 正在处理图像：extracted_frames\frame_116.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_116.jpg，成功！
# 正在处理图像：extracted_frames\frame_117.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_117.jpg，成功！
# 正在处理图像：extracted_frames\frame_118.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_118.jpg，成功！
# 正在处理图像：extracted_frames\frame_119.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_119.jpg，成功！
# 正在处理图像：extracted_frames\frame_120.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_120.jpg，成功！
# 正在处理图像：extracted_frames\frame_121.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_121.jpg，成功！
# 正在处理图像：extracted_frames\frame_122.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_122.jpg，成功！
# 正在处理图像：extracted_frames\frame_123.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_123.jpg，成功！
# 正在处理图像：extracted_frames\frame_124.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_124.jpg，成功！
# 正在处理图像：extracted_frames\frame_125.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_125.jpg，成功！
# 正在处理图像：extracted_frames\frame_126.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_126.jpg，成功！
# 正在处理图像：extracted_frames\frame_127.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_127.jpg，成功！
# 正在处理图像：extracted_frames\frame_128.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_128.jpg，成功！
# 正在处理图像：extracted_frames\frame_129.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_129.jpg，成功！
# 正在处理图像：extracted_frames\frame_130.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_130.jpg，成功！
# 正在处理图像：extracted_frames\frame_131.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_131.jpg，成功！
# 正在处理图像：extracted_frames\frame_132.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_132.jpg，成功！
# 正在处理图像：extracted_frames\frame_133.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_133.jpg，成功！
# 正在处理图像：extracted_frames\frame_134.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_134.jpg，成功！
# 正在处理图像：extracted_frames\frame_135.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_135.jpg，成功！
# 正在处理图像：extracted_frames\frame_136.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_136.jpg，成功！
# 正在处理图像：extracted_frames\frame_137.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_137.jpg，成功！
# 正在处理图像：extracted_frames\frame_138.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_138.jpg，成功！
# 正在处理图像：extracted_frames\frame_139.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_139.jpg，成功！
# 正在处理图像：extracted_frames\frame_140.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_140.jpg，成功！
# 正在处理图像：extracted_frames\frame_141.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_141.jpg，成功！
# 正在处理图像：extracted_frames\frame_142.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_142.jpg，成功！
# 正在处理图像：extracted_frames\frame_143.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_143.jpg，成功！
# 正在处理图像：extracted_frames\frame_144.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_144.jpg，成功！
# 正在处理图像：extracted_frames\frame_145.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_145.jpg，成功！
# 正在处理图像：extracted_frames\frame_146.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_146.jpg，成功！
# 正在处理图像：extracted_frames\frame_147.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_147.jpg，成功！
# 正在处理图像：extracted_frames\frame_148.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_148.jpg，成功！
# 正在处理图像：extracted_frames\frame_149.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_149.jpg，成功！
# 正在处理图像：extracted_frames\frame_150.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_150.jpg，成功！
# 正在处理图像：extracted_frames\frame_151.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_151.jpg，成功！
# 正在处理图像：extracted_frames\frame_152.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_152.jpg，成功！
# 正在处理图像：extracted_frames\frame_153.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_153.jpg，成功！
# 正在处理图像：extracted_frames\frame_154.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_154.jpg，成功！
# 正在处理图像：extracted_frames\frame_155.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_155.jpg，成功！
# 正在处理图像：extracted_frames\frame_156.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_156.jpg，成功！
# 正在处理图像：extracted_frames\frame_157.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_157.jpg，成功！
# 正在处理图像：extracted_frames\frame_158.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_158.jpg，成功！
# 正在处理图像：extracted_frames\frame_159.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_159.jpg，成功！
# 正在处理图像：extracted_frames\frame_160.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_160.jpg，成功！
# 正在处理图像：extracted_frames\frame_161.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_161.jpg，成功！
# 正在处理图像：extracted_frames\frame_162.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_162.jpg，成功！
# 正在处理图像：extracted_frames\frame_163.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_163.jpg，成功！
# 正在处理图像：extracted_frames\frame_164.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_164.jpg，成功！
# 正在处理图像：extracted_frames\frame_165.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_165.jpg，成功！
# 正在处理图像：extracted_frames\frame_166.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_166.jpg，成功！
# 正在处理图像：extracted_frames\frame_167.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_167.jpg，成功！
# 正在处理图像：extracted_frames\frame_168.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_168.jpg，成功！
# 正在处理图像：extracted_frames\frame_169.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_169.jpg，成功！
# 正在处理图像：extracted_frames\frame_170.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_170.jpg，成功！
# 正在处理图像：extracted_frames\frame_171.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_171.jpg，成功！
# 正在处理图像：extracted_frames\frame_172.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_172.jpg，成功！
# 正在处理图像：extracted_frames\frame_173.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_173.jpg，成功！
# 正在处理图像：extracted_frames\frame_174.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_174.jpg，成功！
# 正在处理图像：extracted_frames\frame_175.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_175.jpg，成功！
# 正在处理图像：extracted_frames\frame_176.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_176.jpg，成功！
# 正在处理图像：extracted_frames\frame_177.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_177.jpg，成功！
# 正在处理图像：extracted_frames\frame_178.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_178.jpg，成功！
# 正在处理图像：extracted_frames\frame_179.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_179.jpg，成功！
# 正在处理图像：extracted_frames\frame_180.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_180.jpg，成功！
# 正在处理图像：extracted_frames\frame_181.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_181.jpg，成功！
# 正在处理图像：extracted_frames\frame_182.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_182.jpg，成功！
# 正在处理图像：extracted_frames\frame_183.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_183.jpg，成功！
# 正在处理图像：extracted_frames\frame_184.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_184.jpg，成功！
# 正在处理图像：extracted_frames\frame_185.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_185.jpg，成功！
# 正在处理图像：extracted_frames\frame_186.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_186.jpg，成功！
# 正在处理图像：extracted_frames\frame_187.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_187.jpg，成功！
# 正在处理图像：extracted_frames\frame_188.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_188.jpg，成功！
# 正在处理图像：extracted_frames\frame_189.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_189.jpg，成功！
# 正在处理图像：extracted_frames\frame_190.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_190.jpg，成功！
# 正在处理图像：extracted_frames\frame_191.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_191.jpg，成功！
# 正在处理图像：extracted_frames\frame_192.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_192.jpg，成功！
# 正在处理图像：extracted_frames\frame_193.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_193.jpg，成功！
# 正在处理图像：extracted_frames\frame_194.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_194.jpg，成功！
# 正在处理图像：extracted_frames\frame_195.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_195.jpg，成功！
# 正在处理图像：extracted_frames\frame_196.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_196.jpg，成功！
# 正在处理图像：extracted_frames\frame_197.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_197.jpg，成功！
# 正在处理图像：extracted_frames\frame_198.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_198.jpg，成功！
# 正在处理图像：extracted_frames\frame_199.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_199.jpg，成功！
# 正在处理图像：extracted_frames\frame_200.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_200.jpg，成功！
# 正在处理图像：extracted_frames\frame_201.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_201.jpg，成功！
# 正在处理图像：extracted_frames\frame_202.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_202.jpg，成功！
# 正在处理图像：extracted_frames\frame_203.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_203.jpg，成功！
# 正在处理图像：extracted_frames\frame_204.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_204.jpg，成功！
# 正在处理图像：extracted_frames\frame_205.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_205.jpg，成功！
# 正在处理图像：extracted_frames\frame_206.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_206.jpg，成功！
# 正在处理图像：extracted_frames\frame_207.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_207.jpg，成功！
# 正在处理图像：extracted_frames\frame_208.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_208.jpg，成功！
# 正在处理图像：extracted_frames\frame_209.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_209.jpg，成功！
# 正在处理图像：extracted_frames\frame_210.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_210.jpg，成功！
# 正在处理图像：extracted_frames\frame_211.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_211.jpg，成功！
# 正在处理图像：extracted_frames\frame_212.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_212.jpg，成功！
# 正在处理图像：extracted_frames\frame_213.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_213.jpg，成功！
# 正在处理图像：extracted_frames\frame_214.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_214.jpg，成功！
# 正在处理图像：extracted_frames\frame_215.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_215.jpg，成功！
# 正在处理图像：extracted_frames\frame_216.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_216.jpg，成功！
# 正在处理图像：extracted_frames\frame_217.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_217.jpg，成功！
# 正在处理图像：extracted_frames\frame_218.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_218.jpg，成功！
# 正在处理图像：extracted_frames\frame_219.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_219.jpg，成功！
# 正在处理图像：extracted_frames\frame_220.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_220.jpg，成功！
# 正在处理图像：extracted_frames\frame_221.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_221.jpg，成功！
# 正在处理图像：extracted_frames\frame_222.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_222.jpg，成功！
# 正在处理图像：extracted_frames\frame_223.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_223.jpg，成功！
# 正在处理图像：extracted_frames\frame_224.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_224.jpg，成功！
# 正在处理图像：extracted_frames\frame_225.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_225.jpg，成功！
# 正在处理图像：extracted_frames\frame_226.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_226.jpg，成功！
# 正在处理图像：extracted_frames\frame_227.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_227.jpg，成功！
# 正在处理图像：extracted_frames\frame_228.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_228.jpg，成功！
# 正在处理图像：extracted_frames\frame_229.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_229.jpg，成功！
# 正在处理图像：extracted_frames\frame_230.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_230.jpg，成功！
# 正在处理图像：extracted_frames\frame_231.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_231.jpg，成功！
# 正在处理图像：extracted_frames\frame_232.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_232.jpg，成功！
# 正在处理图像：extracted_frames\frame_233.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_233.jpg，成功！
# 正在处理图像：extracted_frames\frame_234.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_234.jpg，成功！
# 正在处理图像：extracted_frames\frame_235.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_235.jpg，成功！
# 正在处理图像：extracted_frames\frame_236.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_236.jpg，成功！
# 正在处理图像：extracted_frames\frame_237.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_237.jpg，成功！
# 正在处理图像：extracted_frames\frame_238.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_238.jpg，成功！
# 正在处理图像：extracted_frames\frame_239.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_239.jpg，成功！
# 正在处理图像：extracted_frames\frame_240.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_240.jpg，成功！
# 正在处理图像：extracted_frames\frame_241.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_241.jpg，成功！
# 正在处理图像：extracted_frames\frame_242.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_242.jpg，成功！
# 正在处理图像：extracted_frames\frame_243.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_243.jpg，成功！
# 正在处理图像：extracted_frames\frame_244.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_244.jpg，成功！
# 正在处理图像：extracted_frames\frame_245.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_245.jpg，成功！
# 正在处理图像：extracted_frames\frame_246.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_246.jpg，成功！
# 正在处理图像：extracted_frames\frame_247.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_247.jpg，成功！
# 正在处理图像：extracted_frames\frame_248.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_248.jpg，成功！
# 正在处理图像：extracted_frames\frame_249.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_249.jpg，成功！
# 正在处理图像：extracted_frames\frame_250.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_250.jpg，成功！
# 正在处理图像：extracted_frames\frame_251.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_251.jpg，成功！
# 正在处理图像：extracted_frames\frame_252.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_252.jpg，成功！
# 正在处理图像：extracted_frames\frame_253.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_253.jpg，成功！
# 正在处理图像：extracted_frames\frame_254.jpg，尺寸为：640x512
# 已保存裁剪后的图像：cropped_frames\frame_254.jpg，成功！
# 所有图像裁剪已完成。

# %%
from PIL import Image
import os

# 定义文件夹路径
input_folder = r'D:\Program\d2l\battery\cropped_frames'
output_folder = r'D:\Program\d2l\battery\cropped_frames1'

# 确保输出文件夹存在
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# 遍历文件夹中的所有文件
for filename in os.listdir(input_folder):
    if filename.endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
        # 打开图像
        img_path = os.path.join(input_folder, filename)
        with Image.open(img_path) as img:
            # 顺时针旋转90度
            rotated_img = img.rotate(270, expand=True)
            # 保存旋转后的图像
            output_path = os.path.join(output_folder, filename)
            rotated_img.save(output_path)

print("所有图片已成功旋转并保存。")
# Out:
# 所有图片已成功旋转并保存。

# %%
# 截图温度像素导出
import cv2
import glob
import os
import numpy as np
# 定义温度标定参数（最白为 55 摄氏度，最黑为 22 摄氏度）
min_temp = 22  # 最低温度
max_temp = 55  # 最高温度

# 输入和输出文件夹
input_folder = 'cropped_frames1'
output_folder = 'temperature_results_with_coordinates'
os.makedirs(output_folder, exist_ok=True)

# 获取所有裁剪后的图像文件名
image_files = glob.glob(os.path.join(input_folder, '*.jpg'))

for img_file in image_files:
    # 读取图像
    image = cv2.imread(img_file)
    if image is None:
        print(f"无法读取图像文件：{img_file}")
        continue

    # 将图像转换为灰度图
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # 将灰度值转换为温度值
    # 使用线性插值公式：温度 = min_temp + (灰度值 / 255) * (max_temp - min_temp)
    temperature_matrix = min_temp + (gray_image / 255.0) * (max_temp - min_temp)

    # 生成像素坐标矩阵
    height, width = gray_image.shape
    x_coords = np.arange(0, width)
    y_coords = np.arange(0, height)
    xx, yy = np.meshgrid(x_coords, y_coords)

    # 将温度值和对应的坐标展开为一维数组
    x_flat = xx.flatten()
    y_flat = yy.flatten()
    temp_flat = temperature_matrix.flatten()

    # 将数据组合为 (X, Y, Temperature)
    data = np.column_stack((x_flat, y_flat, temp_flat))

    # 保存数据为文本文件
    txt_filename = os.path.basename(img_file).replace('.jpg', '_temperature_coordinates.txt')
    txt_path = os.path.join(output_folder, txt_filename)
    np.savetxt(txt_path, data, fmt='%.4f', delimiter='\t', header='X(cm)\tY(cm)\tTemperature(°C)', comments='')
    print(f"已保存温度坐标数据：{txt_path}")

    # 可视化温度矩阵（可选）
    # 将温度矩阵归一化到 0-255，用于显示或保存为图像
    normalized_temp = cv2.normalize(temperature_matrix, None, 0, 255, cv2.NORM_MINMAX)
    normalized_temp = normalized_temp.astype(np.uint8)

    # 伪彩色显示温度分布（可选）
    color_map = cv2.applyColorMap(normalized_temp, cv2.COLORMAP_JET)

    # 保存温度矩阵为图像
    result_filename = os.path.basename(img_file).replace('.jpg', '_temperature.jpg')
    result_path = os.path.join(output_folder, result_filename)
    cv2.imwrite(result_path, color_map)
    print(f"已保存温度分布图：{result_path}")

print('所有温度像素导出已完成。')
# Out:
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_1_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_1_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_10_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_10_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_100_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_100_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_101_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_101_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_102_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_102_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_103_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_103_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_104_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_104_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_105_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_105_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_106_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_106_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_107_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_107_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_108_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_108_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_109_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_109_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_11_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_11_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_110_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_110_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_111_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_111_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_112_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_112_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_113_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_113_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_114_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_114_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_115_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_115_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_116_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_116_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_117_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_117_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_118_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_118_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_119_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_119_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_12_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_12_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_120_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_120_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_121_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_121_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_122_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_122_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_123_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_123_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_124_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_124_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_125_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_125_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_126_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_126_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_127_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_127_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_128_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_128_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_129_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_129_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_13_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_13_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_130_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_130_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_131_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_131_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_132_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_132_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_133_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_133_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_134_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_134_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_135_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_135_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_136_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_136_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_137_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_137_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_138_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_138_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_139_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_139_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_14_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_14_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_140_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_140_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_141_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_141_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_142_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_142_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_143_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_143_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_144_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_144_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_145_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_145_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_146_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_146_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_147_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_147_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_148_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_148_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_149_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_149_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_15_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_15_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_150_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_150_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_151_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_151_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_152_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_152_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_153_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_153_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_154_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_154_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_155_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_155_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_156_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_156_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_157_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_157_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_158_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_158_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_159_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_159_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_16_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_16_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_160_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_160_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_161_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_161_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_162_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_162_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_163_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_163_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_164_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_164_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_165_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_165_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_166_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_166_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_167_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_167_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_168_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_168_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_169_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_169_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_17_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_17_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_170_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_170_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_171_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_171_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_172_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_172_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_173_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_173_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_174_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_174_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_175_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_175_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_176_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_176_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_177_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_177_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_178_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_178_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_179_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_179_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_18_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_18_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_180_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_180_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_181_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_181_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_182_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_182_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_183_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_183_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_184_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_184_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_185_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_185_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_186_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_186_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_187_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_187_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_188_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_188_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_189_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_189_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_19_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_19_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_190_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_190_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_191_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_191_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_192_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_192_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_193_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_193_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_194_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_194_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_195_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_195_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_196_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_196_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_197_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_197_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_198_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_198_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_199_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_199_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_2_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_2_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_20_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_20_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_200_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_200_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_201_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_201_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_202_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_202_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_203_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_203_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_204_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_204_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_205_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_205_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_206_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_206_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_207_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_207_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_208_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_208_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_209_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_209_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_21_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_21_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_210_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_210_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_211_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_211_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_212_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_212_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_213_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_213_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_214_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_214_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_215_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_215_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_216_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_216_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_217_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_217_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_218_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_218_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_219_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_219_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_22_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_22_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_220_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_220_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_221_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_221_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_222_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_222_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_223_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_223_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_224_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_224_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_225_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_225_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_226_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_226_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_227_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_227_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_228_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_228_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_229_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_229_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_23_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_23_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_230_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_230_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_231_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_231_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_232_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_232_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_233_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_233_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_234_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_234_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_235_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_235_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_236_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_236_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_237_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_237_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_238_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_238_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_239_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_239_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_24_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_24_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_240_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_240_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_241_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_241_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_242_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_242_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_243_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_243_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_244_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_244_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_245_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_245_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_246_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_246_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_247_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_247_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_248_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_248_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_249_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_249_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_25_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_25_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_250_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_250_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_251_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_251_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_252_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_252_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_253_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_253_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_254_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_254_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_26_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_26_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_27_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_27_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_28_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_28_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_29_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_29_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_3_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_3_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_30_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_30_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_31_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_31_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_32_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_32_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_33_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_33_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_34_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_34_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_35_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_35_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_36_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_36_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_37_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_37_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_38_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_38_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_39_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_39_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_4_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_4_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_40_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_40_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_41_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_41_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_42_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_42_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_43_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_43_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_44_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_44_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_45_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_45_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_46_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_46_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_47_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_47_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_48_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_48_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_49_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_49_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_5_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_5_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_50_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_50_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_51_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_51_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_52_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_52_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_53_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_53_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_54_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_54_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_55_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_55_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_56_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_56_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_57_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_57_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_58_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_58_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_59_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_59_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_6_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_6_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_60_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_60_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_61_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_61_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_62_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_62_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_63_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_63_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_64_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_64_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_65_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_65_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_66_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_66_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_67_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_67_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_68_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_68_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_69_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_69_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_7_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_7_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_70_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_70_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_71_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_71_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_72_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_72_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_73_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_73_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_74_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_74_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_75_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_75_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_76_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_76_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_77_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_77_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_78_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_78_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_79_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_79_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_8_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_8_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_80_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_80_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_81_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_81_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_82_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_82_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_83_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_83_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_84_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_84_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_85_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_85_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_86_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_86_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_87_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_87_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_88_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_88_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_89_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_89_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_9_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_9_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_90_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_90_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_91_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_91_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_92_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_92_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_93_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_93_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_94_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_94_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_95_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_95_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_96_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_96_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_97_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_97_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_98_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_98_temperature.jpg
# 已保存温度坐标数据：temperature_results_with_coordinates\frame_99_temperature_coordinates.txt
# 已保存温度分布图：temperature_results_with_coordinates\frame_99_temperature.jpg
# 所有温度像素导出已完成。

# %%
# OFDR数据处理
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
import pandas as pd  # 导入 pandas 库

# 全局设置字体为 Arial
plt.rcParams['font.family'] = 'Arial'

def plot_spiral(file_path):
    # 读取 Excel 数据
    df = pd.read_excel(file_path, header=0)  # header=0 表示第一行是列名
    
    # 假设每一列都是一组新的温度数据
    temperature_columns = df.columns  # 获取所有列名
    num_points = df.shape[0]  # 每组温度数据的点数

    # 创建保存数据的文件夹
    data_output_folder = 'scatter_data'
    image_output_folder = 'image_data1'
    os.makedirs(data_output_folder, exist_ok=True)
    os.makedirs(image_output_folder, exist_ok=True)
    
    # 图像参数
    img_size = 260  # 像素
    physical_size_cm = 6.5  # 物理大小为 6.5 cm
    pixels_per_cm = img_size / physical_size_cm
    
    # 遍历每一列温度数据
    for col_idx, col_name in enumerate(temperature_columns):
        temperatures_full = df[col_name].values + 22  # 假设温度需要加上 22

        # 检查数据长度是否足够
        if len(temperatures_full) < 10:
            print(f"列 '{col_name}' 的数据点不足，已跳过。")
            continue
            
        # 去除首尾各一些点
        temperatures = temperatures_full[70:-65]

        # 更新数据点数
        num_points = len(temperatures)

        # 螺旋参数设置
        a = 0  # 螺旋初始半径
        b = 2.5 / (5 * 2 * np.pi)  # 控制螺旋增长率，可根据需要调整

        # 计算角度 theta，长度为温度数据的点数
        theta = np.linspace(-6 * 2 * np.pi, 0, num_points)
        r = a + b * theta  # 计算半径 r

        # 坐标转换为二维平面上的点
        X = r * np.cos(theta)
        Y = r * np.sin(theta)

        # 计算每一步的弧长和累积弧长
        arc_lengths = np.sqrt(np.diff(X)**2 + np.diff(Y)**2)
        cumulative_arc_lengths = np.zeros_like(X)
        cumulative_arc_lengths[1:] = np.cumsum(arc_lengths)

        # 插值函数，确保温度数据与空间位置对齐
        interp_x = interp1d(cumulative_arc_lengths, X, kind='linear', fill_value="extrapolate")
        interp_y = interp1d(cumulative_arc_lengths, Y, kind='linear', fill_value="extrapolate")

        # 计算新的点的位置
        new_arcs = np.linspace(0, cumulative_arc_lengths[-1], num_points)
        X_new = interp_x(new_arcs)
        Y_new = interp_y(new_arcs)

        # 获取温度的最小值和最大值
        vmin, vmax = min(temperatures), max(temperatures)
        
        # 设置共享的绘图参数
        plot_params = {
            'xlabel': 'X Coordinate',
            'ylabel': 'Y Coordinate',
            'aspect': 'equal',  # 确保 x 和 y 轴的比例相同
        }

        # 函数：绘制单个图
        def plot_single(ax):
            scatter = ax.scatter(X_new, Y_new, c=temperatures, cmap='jet', s=50, edgecolors='k', vmin=vmin, vmax=vmax)
            title = f'Spiral Plot - {col_name}'

            ax.set(**plot_params)
            ax.set_title(title)
            # 添加颜色条
            cbar = plt.colorbar(scatter, ax=ax)
            cbar.set_label('Temperature (\u00b0C)')

        # 绘图
        fig, ax = plt.subplots(figsize=(6, 6))
        plot_single(ax)
        plt.tight_layout()

        # 保存图像
        #output_filename = os.path.join(image_output_folder, f'spiral_plot_{col_name}.png')
        #plt.savefig(output_filename, dpi=300)
        #print(f"已保存图像：{output_filename}")

        # 保存散点数据为文本文件
        data_output_filename = f'scatter_data_{col_name}.txt'
        data_output_path = os.path.join(data_output_folder, data_output_filename)
        # 组合数据为 (X, Y, Temperature)
        scatter_data = np.column_stack((X_new, Y_new, temperatures))
        # 保存为文本文件，设置格式
        np.savetxt(data_output_path, scatter_data, fmt='%.6f', delimiter='\t', header='X\tY\tTemperature(\u00b0C)', comments='')
        print(f"已保存散点数据：{data_output_path}")

        # 创建 260x260 的图像数组，初始化为 20
        image_array = np.full((img_size, img_size), 22, dtype=np.float32)

        # 将 X_new 和 Y_new 映射到图像的像素坐标
        x_pixel = np.floor((X_new + (physical_size_cm / 2)) * pixels_per_cm).astype(int)
        y_pixel = np.floor((Y_new + (physical_size_cm / 2)) * pixels_per_cm).astype(int)

        # 确保像素坐标在 [0, img_size-1] 范围内
        x_pixel = np.clip(x_pixel, 0, img_size - 1)
        y_pixel = np.clip(y_pixel, 0, img_size - 1)

        # 创建一个用于统计每个像素的温度值和计数的数组
        temperature_sum = np.zeros((img_size, img_size), dtype=np.float32)
        temperature_count = np.zeros((img_size, img_size), dtype=np.int32)

        # 使用矩量化操作进行高效的累加
        indices = y_pixel * img_size + x_pixel  # 计算一维索引
        temperature_sum_flat = np.bincount(indices, weights=temperatures, minlength=img_size*img_size)
        temperature_count_flat = np.bincount(indices, minlength=img_size*img_size)

        # 重塑为二维数组
        temperature_sum = temperature_sum_flat.reshape((img_size, img_size))
        temperature_count = temperature_count_flat.reshape((img_size, img_size))

        # 计算平均温度
        non_zero_mask = temperature_count > 0
        image_array[non_zero_mask] = temperature_sum[non_zero_mask] / temperature_count[non_zero_mask]

        # 其余像素保持为 0

        # 保存图像数组为 .txt 文件
        y_indices, x_indices = np.indices(image_array.shape)
        x_flat = x_indices.flatten()
        y_flat = y_indices.flatten()
        temp_flat = image_array.flatten()
        
        # 组合数据为 (X_pixel, Y_pixel, Temperature)
        data_to_save = np.column_stack((x_flat, y_flat, temp_flat))

        # 定义保存的文件名
        txt_filename = f'image_data_{col_name}.txt'
        txt_path = os.path.join(image_output_folder, txt_filename)

        # 保存为文本文件，第一行为标题
        header = 'X\tY\tTemperature(\u00b0C)'
        #np.savetxt(txt_path, data_to_save, fmt='%.6f', delimiter='\t', header=header, comments='')
        #print(f"已保存图像数据为文本文件：{txt_path}")

        # 保存 260x260 的纯图像，不含坐标轴和颜色条
        plt.figure(figsize=(6, 6))
        plt.imshow(image_array, cmap='gray', origin='lower', vmin=22, vmax=55)
        
        # 移除坐标轴和刻度
        plt.axis('off')
        
        # 如果不需要标题，注释或移除以下行
        # plt.title(f'Temperature Image - {col_name}')
        
        # 调整布局，去除多余的边距
        plt.tight_layout(pad=0)
        
        # 保存图像，去除边框
        image_png_filename = os.path.join(image_output_folder, f'image_plot_{col_name}.png')
        plt.savefig(image_png_filename, dpi=300, bbox_inches='tight', pad_inches=0)
        print(f"已保存图像图片：{image_png_filename}")
        plt.close()


        # 关闭图形，防止重复绘制
        plt.close(fig)

file_path = 'ofdr_OLD.xlsx'
plot_spiral(file_path)
# Out:
# 已保存散点数据：scatter_data\scatter_data_1.txt
# 已保存图像图片：image_data1\image_plot_1.png
# 已保存散点数据：scatter_data\scatter_data_2.txt
# 已保存图像图片：image_data1\image_plot_2.png
# 已保存散点数据：scatter_data\scatter_data_3.txt
# 已保存图像图片：image_data1\image_plot_3.png
# 已保存散点数据：scatter_data\scatter_data_4.txt
# 已保存图像图片：image_data1\image_plot_4.png
# 已保存散点数据：scatter_data\scatter_data_5.txt
# 已保存图像图片：image_data1\image_plot_5.png
# 已保存散点数据：scatter_data\scatter_data_6.txt
# 已保存图像图片：image_data1\image_plot_6.png
# 已保存散点数据：scatter_data\scatter_data_7.txt
# 已保存图像图片：image_data1\image_plot_7.png
# 已保存散点数据：scatter_data\scatter_data_8.txt
# 已保存图像图片：image_data1\image_plot_8.png
# 已保存散点数据：scatter_data\scatter_data_9.txt
# 已保存图像图片：image_data1\image_plot_9.png
# 已保存散点数据：scatter_data\scatter_data_10.txt
# 已保存图像图片：image_data1\image_plot_10.png
# 已保存散点数据：scatter_data\scatter_data_11.txt
# 已保存图像图片：image_data1\image_plot_11.png
# 已保存散点数据：scatter_data\scatter_data_12.txt
# 已保存图像图片：image_data1\image_plot_12.png

# %%
import os
import numpy as np
from PIL import Image, ImageEnhance, ImageOps, ImageFilter, ImageChops
import random

# 定义数据路径
sparse_folder = r'D:\Program\d2l\battery\image_data'   # 稀疏数据文件夹路径
dense_folder = r'D:\Program\d2l\battery\cropped_frames1'    # 密集数据文件夹路径

# 定义输出文件夹
sparse_output_folder = r'D:\Program\d2l\battery\sparse_data'  # 存储增强后的稀疏数据
dense_output_folder = r'D:\Program\d2l\battery\dense_data'    # 存储增强后的密集数据

# 创建输出文件夹（如果不存在）
os.makedirs(sparse_output_folder, exist_ok=True)
os.makedirs(dense_output_folder, exist_ok=True)

# 获取稀疏数据文件列表（图像文件，如.jpg, .png）
sparse_files = sorted([f for f in os.listdir(sparse_folder) if f.endswith(('.jpg', '.png', '.jpeg', '.bmp'))])

# 获取密集数据文件列表（图像文件）
dense_files = sorted([f for f in os.listdir(dense_folder) if f.endswith(('.jpg', '.png', '.jpeg', '.bmp'))])

# 检查文件数量是否一致
if len(sparse_files) != len(dense_files):
    print("稀疏数据文件和密集数据文件数量不一致，请检查文件夹。")
else:
    print(f"检测到 {len(sparse_files)} 组数据。")

# 添加噪声函数
def add_noise(image, noise_level):
    img_array = np.array(image)
    noise = np.random.randint(0, noise_level, img_array.shape, dtype='uint8')
    img_array = img_array + noise
    img_array = np.clip(img_array, 0, 255)
    return Image.fromarray(img_array.astype('uint8'))

# 固定裁剪函数：裁剪图像的右下角1/4部分
def fixed_crop(image):
    width, height = image.size
    new_width = width // 2
    new_height = height // 2
    left = width - new_width
    top = height - new_height
    return image.crop((left, top, left + new_width, top + new_height))

# 定义增强操作函数
def rotate_image(image, angle):
    return image.rotate(angle, expand=True)

def flip_image(image, mode):
    return image.transpose(mode)

def translate_image(image, dx, dy):
    return ImageChops.offset(image, dx, dy)

def scale_image(image, scale_x, scale_y):
    new_width = int(image.width * scale_x)
    new_height = int(image.height * scale_y)
    return image.resize((new_width, new_height), Image.BICUBIC)

def adjust_brightness(image, factor):
    return ImageEnhance.Brightness(image).enhance(factor)

def adjust_contrast(image, factor):
    return ImageEnhance.Contrast(image).enhance(factor)

def apply_gaussian_blur(image, radius):
    return image.filter(ImageFilter.GaussianBlur(radius=radius))

# 主函数：对数据进行处理并数据增强
def process_and_augment_data():
    # 定义数据增强操作列表，每个操作包含一个名称和对应的函数
    augmentations = [
        ('rotate_90', rotate_image, {'angle': 90}),
        ('rotate_180', rotate_image, {'angle': 180}),
        ('flip_left_right', flip_image, {'mode': Image.FLIP_LEFT_RIGHT}),
        ('flip_top_bottom', flip_image, {'mode': Image.FLIP_TOP_BOTTOM}),
        ('translate', translate_image, {}),
        ('scale', scale_image, {}),
        ('brightness', adjust_brightness, {}),
        ('contrast', adjust_contrast, {}),
        ('gaussian_blur', apply_gaussian_blur, {}),
        ('noise', add_noise, {}),
        ('fixed_crop', fixed_crop, {}),
    ]

    total_augmented = 0

    for idx in range(len(sparse_files)):
        sparse_file = sparse_files[idx]
        dense_file = dense_files[idx]

        # 构建完整路径
        sparse_path = os.path.join(sparse_folder, sparse_file)
        dense_path = os.path.join(dense_folder, dense_file)

        # 读取图像数据
        sparse_image = Image.open(sparse_path)
        dense_image = Image.open(dense_path)

        # 创建用于保存增强数据的文件名基础
        base_name_sparse = os.path.splitext(sparse_file)[0]
        base_name_dense = os.path.splitext(dense_file)[0]

        for aug_name, aug_func, params in augmentations:
            # 在这里生成随机参数
            if aug_name == 'translate':
                dx = random.randint(-100, 100)
                dy = random.randint(-100, 100)
                params = {'dx': dx, 'dy': dy}
            elif aug_name == 'scale':
                scale_x = random.uniform(0.5, 1.5)
                scale_y = random.uniform(0.5, 1.5)
                params = {'scale_x': scale_x, 'scale_y': scale_y}
            elif aug_name == 'brightness':
                factor = random.uniform(0.7, 1.3)
                params = {'factor': factor}
            elif aug_name == 'contrast':
                factor = random.uniform(0.7, 1.3)
                params = {'factor': factor}
            elif aug_name == 'gaussian_blur':
                radius = random.uniform(0.0, 2.0)
                params = {'radius': radius}
            elif aug_name == 'noise':
                noise_level = random.randint(1, 50)
                params = {'noise_level': noise_level}
            elif aug_name == 'fixed_crop':
                # 固定裁剪不需要额外参数
                pass
            else:
                # 对于固定参数的增强操作，使用预设的 params
                pass

            # 应用变换，使用相同的参数
            sparse_aug = aug_func(sparse_image, **params)
            dense_aug = aug_func(dense_image, **params)

            # 保存增强后的数据
            sparse_output_file = f'{base_name_sparse}_{aug_name}.png'
            dense_output_file = f'{base_name_dense}_{aug_name}.png'

            sparse_output_path = os.path.join(sparse_output_folder, sparse_output_file)
            dense_output_path = os.path.join(dense_output_folder, dense_output_file)

            # 保存图像
            sparse_aug.save(sparse_output_path)
            dense_aug.save(dense_output_path)

            print(f"已生成增强数据：{sparse_output_file} 和 {dense_output_file}")
            total_augmented += 1

    print(f"数据增强完成，共生成 {total_augmented} 组增强数据。")

# 执行数据处理和增强
process_and_augment_data()
# Out:
# 检测到 155 组数据。
# 已生成增强数据：image_plot_1_rotate_90.png 和 frame_1_rotate_90.png
# 已生成增强数据：image_plot_1_rotate_180.png 和 frame_1_rotate_180.png
# 已生成增强数据：image_plot_1_flip_left_right.png 和 frame_1_flip_left_right.png
# 已生成增强数据：image_plot_1_flip_top_bottom.png 和 frame_1_flip_top_bottom.png
# 已生成增强数据：image_plot_1_translate.png 和 frame_1_translate.png
# 已生成增强数据：image_plot_1_scale.png 和 frame_1_scale.png
# 已生成增强数据：image_plot_1_brightness.png 和 frame_1_brightness.png
# 已生成增强数据：image_plot_1_contrast.png 和 frame_1_contrast.png
# 已生成增强数据：image_plot_1_gaussian_blur.png 和 frame_1_gaussian_blur.png
# 已生成增强数据：image_plot_1_noise.png 和 frame_1_noise.png
# 已生成增强数据：image_plot_1_fixed_crop.png 和 frame_1_fixed_crop.png
# 已生成增强数据：image_plot_10_rotate_90.png 和 frame_10_rotate_90.png
# 已生成增强数据：image_plot_10_rotate_180.png 和 frame_10_rotate_180.png
# 已生成增强数据：image_plot_10_flip_left_right.png 和 frame_10_flip_left_right.png
# 已生成增强数据：image_plot_10_flip_top_bottom.png 和 frame_10_flip_top_bottom.png
# 已生成增强数据：image_plot_10_translate.png 和 frame_10_translate.png
# 已生成增强数据：image_plot_10_scale.png 和 frame_10_scale.png
# 已生成增强数据：image_plot_10_brightness.png 和 frame_10_brightness.png
# 已生成增强数据：image_plot_10_contrast.png 和 frame_10_contrast.png
# 已生成增强数据：image_plot_10_gaussian_blur.png 和 frame_10_gaussian_blur.png
# 已生成增强数据：image_plot_10_noise.png 和 frame_10_noise.png
# 已生成增强数据：image_plot_10_fixed_crop.png 和 frame_10_fixed_crop.png
# 已生成增强数据：image_plot_100_rotate_90.png 和 frame_100_rotate_90.png
# 已生成增强数据：image_plot_100_rotate_180.png 和 frame_100_rotate_180.png
# 已生成增强数据：image_plot_100_flip_left_right.png 和 frame_100_flip_left_right.png
# 已生成增强数据：image_plot_100_flip_top_bottom.png 和 frame_100_flip_top_bottom.png
# 已生成增强数据：image_plot_100_translate.png 和 frame_100_translate.png
# 已生成增强数据：image_plot_100_scale.png 和 frame_100_scale.png
# 已生成增强数据：image_plot_100_brightness.png 和 frame_100_brightness.png
# 已生成增强数据：image_plot_100_contrast.png 和 frame_100_contrast.png
# 已生成增强数据：image_plot_100_gaussian_blur.png 和 frame_100_gaussian_blur.png
# 已生成增强数据：image_plot_100_noise.png 和 frame_100_noise.png
# 已生成增强数据：image_plot_100_fixed_crop.png 和 frame_100_fixed_crop.png
# 已生成增强数据：image_plot_101_rotate_90.png 和 frame_101_rotate_90.png
# 已生成增强数据：image_plot_101_rotate_180.png 和 frame_101_rotate_180.png
# 已生成增强数据：image_plot_101_flip_left_right.png 和 frame_101_flip_left_right.png
# 已生成增强数据：image_plot_101_flip_top_bottom.png 和 frame_101_flip_top_bottom.png
# 已生成增强数据：image_plot_101_translate.png 和 frame_101_translate.png
# 已生成增强数据：image_plot_101_scale.png 和 frame_101_scale.png
# 已生成增强数据：image_plot_101_brightness.png 和 frame_101_brightness.png
# 已生成增强数据：image_plot_101_contrast.png 和 frame_101_contrast.png
# 已生成增强数据：image_plot_101_gaussian_blur.png 和 frame_101_gaussian_blur.png
# 已生成增强数据：image_plot_101_noise.png 和 frame_101_noise.png
# 已生成增强数据：image_plot_101_fixed_crop.png 和 frame_101_fixed_crop.png
# 已生成增强数据：image_plot_102_rotate_90.png 和 frame_102_rotate_90.png
# 已生成增强数据：image_plot_102_rotate_180.png 和 frame_102_rotate_180.png
# 已生成增强数据：image_plot_102_flip_left_right.png 和 frame_102_flip_left_right.png
# 已生成增强数据：image_plot_102_flip_top_bottom.png 和 frame_102_flip_top_bottom.png
# 已生成增强数据：image_plot_102_translate.png 和 frame_102_translate.png
# 已生成增强数据：image_plot_102_scale.png 和 frame_102_scale.png
# 已生成增强数据：image_plot_102_brightness.png 和 frame_102_brightness.png
# 已生成增强数据：image_plot_102_contrast.png 和 frame_102_contrast.png
# 已生成增强数据：image_plot_102_gaussian_blur.png 和 frame_102_gaussian_blur.png
# 已生成增强数据：image_plot_102_noise.png 和 frame_102_noise.png
# 已生成增强数据：image_plot_102_fixed_crop.png 和 frame_102_fixed_crop.png
# 已生成增强数据：image_plot_103_rotate_90.png 和 frame_103_rotate_90.png
# 已生成增强数据：image_plot_103_rotate_180.png 和 frame_103_rotate_180.png
# 已生成增强数据：image_plot_103_flip_left_right.png 和 frame_103_flip_left_right.png
# 已生成增强数据：image_plot_103_flip_top_bottom.png 和 frame_103_flip_top_bottom.png
# 已生成增强数据：image_plot_103_translate.png 和 frame_103_translate.png
# 已生成增强数据：image_plot_103_scale.png 和 frame_103_scale.png
# 已生成增强数据：image_plot_103_brightness.png 和 frame_103_brightness.png
# 已生成增强数据：image_plot_103_contrast.png 和 frame_103_contrast.png
# 已生成增强数据：image_plot_103_gaussian_blur.png 和 frame_103_gaussian_blur.png
# 已生成增强数据：image_plot_103_noise.png 和 frame_103_noise.png
# 已生成增强数据：image_plot_103_fixed_crop.png 和 frame_103_fixed_crop.png
# 已生成增强数据：image_plot_104_rotate_90.png 和 frame_104_rotate_90.png
# 已生成增强数据：image_plot_104_rotate_180.png 和 frame_104_rotate_180.png
# 已生成增强数据：image_plot_104_flip_left_right.png 和 frame_104_flip_left_right.png
# 已生成增强数据：image_plot_104_flip_top_bottom.png 和 frame_104_flip_top_bottom.png
# 已生成增强数据：image_plot_104_translate.png 和 frame_104_translate.png
# 已生成增强数据：image_plot_104_scale.png 和 frame_104_scale.png
# 已生成增强数据：image_plot_104_brightness.png 和 frame_104_brightness.png
# 已生成增强数据：image_plot_104_contrast.png 和 frame_104_contrast.png
# 已生成增强数据：image_plot_104_gaussian_blur.png 和 frame_104_gaussian_blur.png
# 已生成增强数据：image_plot_104_noise.png 和 frame_104_noise.png
# 已生成增强数据：image_plot_104_fixed_crop.png 和 frame_104_fixed_crop.png
# 已生成增强数据：image_plot_105_rotate_90.png 和 frame_105_rotate_90.png
# 已生成增强数据：image_plot_105_rotate_180.png 和 frame_105_rotate_180.png
# 已生成增强数据：image_plot_105_flip_left_right.png 和 frame_105_flip_left_right.png
# 已生成增强数据：image_plot_105_flip_top_bottom.png 和 frame_105_flip_top_bottom.png
# 已生成增强数据：image_plot_105_translate.png 和 frame_105_translate.png
# 已生成增强数据：image_plot_105_scale.png 和 frame_105_scale.png
# 已生成增强数据：image_plot_105_brightness.png 和 frame_105_brightness.png
# 已生成增强数据：image_plot_105_contrast.png 和 frame_105_contrast.png
# 已生成增强数据：image_plot_105_gaussian_blur.png 和 frame_105_gaussian_blur.png
# 已生成增强数据：image_plot_105_noise.png 和 frame_105_noise.png
# 已生成增强数据：image_plot_105_fixed_crop.png 和 frame_105_fixed_crop.png
# 已生成增强数据：image_plot_106_rotate_90.png 和 frame_106_rotate_90.png
# 已生成增强数据：image_plot_106_rotate_180.png 和 frame_106_rotate_180.png
# 已生成增强数据：image_plot_106_flip_left_right.png 和 frame_106_flip_left_right.png
# 已生成增强数据：image_plot_106_flip_top_bottom.png 和 frame_106_flip_top_bottom.png
# 已生成增强数据：image_plot_106_translate.png 和 frame_106_translate.png
# 已生成增强数据：image_plot_106_scale.png 和 frame_106_scale.png
# 已生成增强数据：image_plot_106_brightness.png 和 frame_106_brightness.png
# 已生成增强数据：image_plot_106_contrast.png 和 frame_106_contrast.png
# 已生成增强数据：image_plot_106_gaussian_blur.png 和 frame_106_gaussian_blur.png
# 已生成增强数据：image_plot_106_noise.png 和 frame_106_noise.png
# 已生成增强数据：image_plot_106_fixed_crop.png 和 frame_106_fixed_crop.png
# 已生成增强数据：image_plot_107_rotate_90.png 和 frame_107_rotate_90.png
# 已生成增强数据：image_plot_107_rotate_180.png 和 frame_107_rotate_180.png
# 已生成增强数据：image_plot_107_flip_left_right.png 和 frame_107_flip_left_right.png
# 已生成增强数据：image_plot_107_flip_top_bottom.png 和 frame_107_flip_top_bottom.png
# 已生成增强数据：image_plot_107_translate.png 和 frame_107_translate.png
# 已生成增强数据：image_plot_107_scale.png 和 frame_107_scale.png
# 已生成增强数据：image_plot_107_brightness.png 和 frame_107_brightness.png
# 已生成增强数据：image_plot_107_contrast.png 和 frame_107_contrast.png
# 已生成增强数据：image_plot_107_gaussian_blur.png 和 frame_107_gaussian_blur.png
# 已生成增强数据：image_plot_107_noise.png 和 frame_107_noise.png
# 已生成增强数据：image_plot_107_fixed_crop.png 和 frame_107_fixed_crop.png
# 已生成增强数据：image_plot_108_rotate_90.png 和 frame_108_rotate_90.png
# 已生成增强数据：image_plot_108_rotate_180.png 和 frame_108_rotate_180.png
# 已生成增强数据：image_plot_108_flip_left_right.png 和 frame_108_flip_left_right.png
# 已生成增强数据：image_plot_108_flip_top_bottom.png 和 frame_108_flip_top_bottom.png
# 已生成增强数据：image_plot_108_translate.png 和 frame_108_translate.png
# 已生成增强数据：image_plot_108_scale.png 和 frame_108_scale.png
# 已生成增强数据：image_plot_108_brightness.png 和 frame_108_brightness.png
# 已生成增强数据：image_plot_108_contrast.png 和 frame_108_contrast.png
# 已生成增强数据：image_plot_108_gaussian_blur.png 和 frame_108_gaussian_blur.png
# 已生成增强数据：image_plot_108_noise.png 和 frame_108_noise.png
# 已生成增强数据：image_plot_108_fixed_crop.png 和 frame_108_fixed_crop.png
# 已生成增强数据：image_plot_109_rotate_90.png 和 frame_109_rotate_90.png
# 已生成增强数据：image_plot_109_rotate_180.png 和 frame_109_rotate_180.png
# 已生成增强数据：image_plot_109_flip_left_right.png 和 frame_109_flip_left_right.png
# 已生成增强数据：image_plot_109_flip_top_bottom.png 和 frame_109_flip_top_bottom.png
# 已生成增强数据：image_plot_109_translate.png 和 frame_109_translate.png
# 已生成增强数据：image_plot_109_scale.png 和 frame_109_scale.png
# 已生成增强数据：image_plot_109_brightness.png 和 frame_109_brightness.png
# 已生成增强数据：image_plot_109_contrast.png 和 frame_109_contrast.png
# 已生成增强数据：image_plot_109_gaussian_blur.png 和 frame_109_gaussian_blur.png
# 已生成增强数据：image_plot_109_noise.png 和 frame_109_noise.png
# 已生成增强数据：image_plot_109_fixed_crop.png 和 frame_109_fixed_crop.png
# 已生成增强数据：image_plot_11_rotate_90.png 和 frame_11_rotate_90.png
# 已生成增强数据：image_plot_11_rotate_180.png 和 frame_11_rotate_180.png
# 已生成增强数据：image_plot_11_flip_left_right.png 和 frame_11_flip_left_right.png
# 已生成增强数据：image_plot_11_flip_top_bottom.png 和 frame_11_flip_top_bottom.png
# 已生成增强数据：image_plot_11_translate.png 和 frame_11_translate.png
# 已生成增强数据：image_plot_11_scale.png 和 frame_11_scale.png
# 已生成增强数据：image_plot_11_brightness.png 和 frame_11_brightness.png
# 已生成增强数据：image_plot_11_contrast.png 和 frame_11_contrast.png
# 已生成增强数据：image_plot_11_gaussian_blur.png 和 frame_11_gaussian_blur.png
# 已生成增强数据：image_plot_11_noise.png 和 frame_11_noise.png
# 已生成增强数据：image_plot_11_fixed_crop.png 和 frame_11_fixed_crop.png
# 已生成增强数据：image_plot_110_rotate_90.png 和 frame_110_rotate_90.png
# 已生成增强数据：image_plot_110_rotate_180.png 和 frame_110_rotate_180.png
# 已生成增强数据：image_plot_110_flip_left_right.png 和 frame_110_flip_left_right.png
# 已生成增强数据：image_plot_110_flip_top_bottom.png 和 frame_110_flip_top_bottom.png
# 已生成增强数据：image_plot_110_translate.png 和 frame_110_translate.png
# 已生成增强数据：image_plot_110_scale.png 和 frame_110_scale.png
# 已生成增强数据：image_plot_110_brightness.png 和 frame_110_brightness.png
# 已生成增强数据：image_plot_110_contrast.png 和 frame_110_contrast.png
# 已生成增强数据：image_plot_110_gaussian_blur.png 和 frame_110_gaussian_blur.png
# 已生成增强数据：image_plot_110_noise.png 和 frame_110_noise.png
# 已生成增强数据：image_plot_110_fixed_crop.png 和 frame_110_fixed_crop.png
# 已生成增强数据：image_plot_111_rotate_90.png 和 frame_111_rotate_90.png
# 已生成增强数据：image_plot_111_rotate_180.png 和 frame_111_rotate_180.png
# 已生成增强数据：image_plot_111_flip_left_right.png 和 frame_111_flip_left_right.png
# 已生成增强数据：image_plot_111_flip_top_bottom.png 和 frame_111_flip_top_bottom.png
# 已生成增强数据：image_plot_111_translate.png 和 frame_111_translate.png
# 已生成增强数据：image_plot_111_scale.png 和 frame_111_scale.png
# 已生成增强数据：image_plot_111_brightness.png 和 frame_111_brightness.png
# 已生成增强数据：image_plot_111_contrast.png 和 frame_111_contrast.png
# 已生成增强数据：image_plot_111_gaussian_blur.png 和 frame_111_gaussian_blur.png
# 已生成增强数据：image_plot_111_noise.png 和 frame_111_noise.png
# 已生成增强数据：image_plot_111_fixed_crop.png 和 frame_111_fixed_crop.png
# 已生成增强数据：image_plot_112_rotate_90.png 和 frame_112_rotate_90.png
# 已生成增强数据：image_plot_112_rotate_180.png 和 frame_112_rotate_180.png
# 已生成增强数据：image_plot_112_flip_left_right.png 和 frame_112_flip_left_right.png
# 已生成增强数据：image_plot_112_flip_top_bottom.png 和 frame_112_flip_top_bottom.png
# 已生成增强数据：image_plot_112_translate.png 和 frame_112_translate.png
# 已生成增强数据：image_plot_112_scale.png 和 frame_112_scale.png
# 已生成增强数据：image_plot_112_brightness.png 和 frame_112_brightness.png
# 已生成增强数据：image_plot_112_contrast.png 和 frame_112_contrast.png
# 已生成增强数据：image_plot_112_gaussian_blur.png 和 frame_112_gaussian_blur.png
# 已生成增强数据：image_plot_112_noise.png 和 frame_112_noise.png
# 已生成增强数据：image_plot_112_fixed_crop.png 和 frame_112_fixed_crop.png
# 已生成增强数据：image_plot_113_rotate_90.png 和 frame_113_rotate_90.png
# 已生成增强数据：image_plot_113_rotate_180.png 和 frame_113_rotate_180.png
# 已生成增强数据：image_plot_113_flip_left_right.png 和 frame_113_flip_left_right.png
# 已生成增强数据：image_plot_113_flip_top_bottom.png 和 frame_113_flip_top_bottom.png
# 已生成增强数据：image_plot_113_translate.png 和 frame_113_translate.png
# 已生成增强数据：image_plot_113_scale.png 和 frame_113_scale.png
# 已生成增强数据：image_plot_113_brightness.png 和 frame_113_brightness.png
# 已生成增强数据：image_plot_113_contrast.png 和 frame_113_contrast.png
# 已生成增强数据：image_plot_113_gaussian_blur.png 和 frame_113_gaussian_blur.png
# 已生成增强数据：image_plot_113_noise.png 和 frame_113_noise.png
# 已生成增强数据：image_plot_113_fixed_crop.png 和 frame_113_fixed_crop.png
# 已生成增强数据：image_plot_114_rotate_90.png 和 frame_114_rotate_90.png
# 已生成增强数据：image_plot_114_rotate_180.png 和 frame_114_rotate_180.png
# 已生成增强数据：image_plot_114_flip_left_right.png 和 frame_114_flip_left_right.png
# 已生成增强数据：image_plot_114_flip_top_bottom.png 和 frame_114_flip_top_bottom.png
# 已生成增强数据：image_plot_114_translate.png 和 frame_114_translate.png
# 已生成增强数据：image_plot_114_scale.png 和 frame_114_scale.png
# 已生成增强数据：image_plot_114_brightness.png 和 frame_114_brightness.png
# 已生成增强数据：image_plot_114_contrast.png 和 frame_114_contrast.png
# 已生成增强数据：image_plot_114_gaussian_blur.png 和 frame_114_gaussian_blur.png
# 已生成增强数据：image_plot_114_noise.png 和 frame_114_noise.png
# 已生成增强数据：image_plot_114_fixed_crop.png 和 frame_114_fixed_crop.png
# 已生成增强数据：image_plot_115_rotate_90.png 和 frame_115_rotate_90.png
# 已生成增强数据：image_plot_115_rotate_180.png 和 frame_115_rotate_180.png
# 已生成增强数据：image_plot_115_flip_left_right.png 和 frame_115_flip_left_right.png
# 已生成增强数据：image_plot_115_flip_top_bottom.png 和 frame_115_flip_top_bottom.png
# 已生成增强数据：image_plot_115_translate.png 和 frame_115_translate.png
# 已生成增强数据：image_plot_115_scale.png 和 frame_115_scale.png
# 已生成增强数据：image_plot_115_brightness.png 和 frame_115_brightness.png
# 已生成增强数据：image_plot_115_contrast.png 和 frame_115_contrast.png
# 已生成增强数据：image_plot_115_gaussian_blur.png 和 frame_115_gaussian_blur.png
# 已生成增强数据：image_plot_115_noise.png 和 frame_115_noise.png
# 已生成增强数据：image_plot_115_fixed_crop.png 和 frame_115_fixed_crop.png
# 已生成增强数据：image_plot_116_rotate_90.png 和 frame_116_rotate_90.png
# 已生成增强数据：image_plot_116_rotate_180.png 和 frame_116_rotate_180.png
# 已生成增强数据：image_plot_116_flip_left_right.png 和 frame_116_flip_left_right.png
# 已生成增强数据：image_plot_116_flip_top_bottom.png 和 frame_116_flip_top_bottom.png
# 已生成增强数据：image_plot_116_translate.png 和 frame_116_translate.png
# 已生成增强数据：image_plot_116_scale.png 和 frame_116_scale.png
# 已生成增强数据：image_plot_116_brightness.png 和 frame_116_brightness.png
# 已生成增强数据：image_plot_116_contrast.png 和 frame_116_contrast.png
# 已生成增强数据：image_plot_116_gaussian_blur.png 和 frame_116_gaussian_blur.png
# 已生成增强数据：image_plot_116_noise.png 和 frame_116_noise.png
# 已生成增强数据：image_plot_116_fixed_crop.png 和 frame_116_fixed_crop.png
# 已生成增强数据：image_plot_117_rotate_90.png 和 frame_117_rotate_90.png
# 已生成增强数据：image_plot_117_rotate_180.png 和 frame_117_rotate_180.png
# 已生成增强数据：image_plot_117_flip_left_right.png 和 frame_117_flip_left_right.png
# 已生成增强数据：image_plot_117_flip_top_bottom.png 和 frame_117_flip_top_bottom.png
# 已生成增强数据：image_plot_117_translate.png 和 frame_117_translate.png
# 已生成增强数据：image_plot_117_scale.png 和 frame_117_scale.png
# 已生成增强数据：image_plot_117_brightness.png 和 frame_117_brightness.png
# 已生成增强数据：image_plot_117_contrast.png 和 frame_117_contrast.png
# 已生成增强数据：image_plot_117_gaussian_blur.png 和 frame_117_gaussian_blur.png
# 已生成增强数据：image_plot_117_noise.png 和 frame_117_noise.png
# 已生成增强数据：image_plot_117_fixed_crop.png 和 frame_117_fixed_crop.png
# 已生成增强数据：image_plot_118_rotate_90.png 和 frame_118_rotate_90.png
# 已生成增强数据：image_plot_118_rotate_180.png 和 frame_118_rotate_180.png
# 已生成增强数据：image_plot_118_flip_left_right.png 和 frame_118_flip_left_right.png
# 已生成增强数据：image_plot_118_flip_top_bottom.png 和 frame_118_flip_top_bottom.png
# 已生成增强数据：image_plot_118_translate.png 和 frame_118_translate.png
# 已生成增强数据：image_plot_118_scale.png 和 frame_118_scale.png
# 已生成增强数据：image_plot_118_brightness.png 和 frame_118_brightness.png
# 已生成增强数据：image_plot_118_contrast.png 和 frame_118_contrast.png
# 已生成增强数据：image_plot_118_gaussian_blur.png 和 frame_118_gaussian_blur.png
# 已生成增强数据：image_plot_118_noise.png 和 frame_118_noise.png
# 已生成增强数据：image_plot_118_fixed_crop.png 和 frame_118_fixed_crop.png
# 已生成增强数据：image_plot_119_rotate_90.png 和 frame_119_rotate_90.png
# 已生成增强数据：image_plot_119_rotate_180.png 和 frame_119_rotate_180.png
# 已生成增强数据：image_plot_119_flip_left_right.png 和 frame_119_flip_left_right.png
# 已生成增强数据：image_plot_119_flip_top_bottom.png 和 frame_119_flip_top_bottom.png
# 已生成增强数据：image_plot_119_translate.png 和 frame_119_translate.png
# 已生成增强数据：image_plot_119_scale.png 和 frame_119_scale.png
# 已生成增强数据：image_plot_119_brightness.png 和 frame_119_brightness.png
# 已生成增强数据：image_plot_119_contrast.png 和 frame_119_contrast.png
# 已生成增强数据：image_plot_119_gaussian_blur.png 和 frame_119_gaussian_blur.png
# 已生成增强数据：image_plot_119_noise.png 和 frame_119_noise.png
# 已生成增强数据：image_plot_119_fixed_crop.png 和 frame_119_fixed_crop.png
# 已生成增强数据：image_plot_12_rotate_90.png 和 frame_12_rotate_90.png
# 已生成增强数据：image_plot_12_rotate_180.png 和 frame_12_rotate_180.png
# 已生成增强数据：image_plot_12_flip_left_right.png 和 frame_12_flip_left_right.png
# 已生成增强数据：image_plot_12_flip_top_bottom.png 和 frame_12_flip_top_bottom.png
# 已生成增强数据：image_plot_12_translate.png 和 frame_12_translate.png
# 已生成增强数据：image_plot_12_scale.png 和 frame_12_scale.png
# 已生成增强数据：image_plot_12_brightness.png 和 frame_12_brightness.png
# 已生成增强数据：image_plot_12_contrast.png 和 frame_12_contrast.png
# 已生成增强数据：image_plot_12_gaussian_blur.png 和 frame_12_gaussian_blur.png
# 已生成增强数据：image_plot_12_noise.png 和 frame_12_noise.png
# 已生成增强数据：image_plot_12_fixed_crop.png 和 frame_12_fixed_crop.png
# 已生成增强数据：image_plot_120_rotate_90.png 和 frame_120_rotate_90.png
# 已生成增强数据：image_plot_120_rotate_180.png 和 frame_120_rotate_180.png
# 已生成增强数据：image_plot_120_flip_left_right.png 和 frame_120_flip_left_right.png
# 已生成增强数据：image_plot_120_flip_top_bottom.png 和 frame_120_flip_top_bottom.png
# 已生成增强数据：image_plot_120_translate.png 和 frame_120_translate.png
# 已生成增强数据：image_plot_120_scale.png 和 frame_120_scale.png
# 已生成增强数据：image_plot_120_brightness.png 和 frame_120_brightness.png
# 已生成增强数据：image_plot_120_contrast.png 和 frame_120_contrast.png
# 已生成增强数据：image_plot_120_gaussian_blur.png 和 frame_120_gaussian_blur.png
# 已生成增强数据：image_plot_120_noise.png 和 frame_120_noise.png
# 已生成增强数据：image_plot_120_fixed_crop.png 和 frame_120_fixed_crop.png
# 已生成增强数据：image_plot_13_rotate_90.png 和 frame_13_rotate_90.png
# 已生成增强数据：image_plot_13_rotate_180.png 和 frame_13_rotate_180.png
# 已生成增强数据：image_plot_13_flip_left_right.png 和 frame_13_flip_left_right.png
# 已生成增强数据：image_plot_13_flip_top_bottom.png 和 frame_13_flip_top_bottom.png
# 已生成增强数据：image_plot_13_translate.png 和 frame_13_translate.png
# 已生成增强数据：image_plot_13_scale.png 和 frame_13_scale.png
# 已生成增强数据：image_plot_13_brightness.png 和 frame_13_brightness.png
# 已生成增强数据：image_plot_13_contrast.png 和 frame_13_contrast.png
# 已生成增强数据：image_plot_13_gaussian_blur.png 和 frame_13_gaussian_blur.png
# 已生成增强数据：image_plot_13_noise.png 和 frame_13_noise.png
# 已生成增强数据：image_plot_13_fixed_crop.png 和 frame_13_fixed_crop.png
# 已生成增强数据：image_plot_14_rotate_90.png 和 frame_14_rotate_90.png
# 已生成增强数据：image_plot_14_rotate_180.png 和 frame_14_rotate_180.png
# 已生成增强数据：image_plot_14_flip_left_right.png 和 frame_14_flip_left_right.png
# 已生成增强数据：image_plot_14_flip_top_bottom.png 和 frame_14_flip_top_bottom.png
# 已生成增强数据：image_plot_14_translate.png 和 frame_14_translate.png
# 已生成增强数据：image_plot_14_scale.png 和 frame_14_scale.png
# 已生成增强数据：image_plot_14_brightness.png 和 frame_14_brightness.png
# 已生成增强数据：image_plot_14_contrast.png 和 frame_14_contrast.png
# 已生成增强数据：image_plot_14_gaussian_blur.png 和 frame_14_gaussian_blur.png
# 已生成增强数据：image_plot_14_noise.png 和 frame_14_noise.png
# 已生成增强数据：image_plot_14_fixed_crop.png 和 frame_14_fixed_crop.png
# 已生成增强数据：image_plot_15_rotate_90.png 和 frame_15_rotate_90.png
# 已生成增强数据：image_plot_15_rotate_180.png 和 frame_15_rotate_180.png
# 已生成增强数据：image_plot_15_flip_left_right.png 和 frame_15_flip_left_right.png
# 已生成增强数据：image_plot_15_flip_top_bottom.png 和 frame_15_flip_top_bottom.png
# 已生成增强数据：image_plot_15_translate.png 和 frame_15_translate.png
# 已生成增强数据：image_plot_15_scale.png 和 frame_15_scale.png
# 已生成增强数据：image_plot_15_brightness.png 和 frame_15_brightness.png
# 已生成增强数据：image_plot_15_contrast.png 和 frame_15_contrast.png
# 已生成增强数据：image_plot_15_gaussian_blur.png 和 frame_15_gaussian_blur.png
# 已生成增强数据：image_plot_15_noise.png 和 frame_15_noise.png
# 已生成增强数据：image_plot_15_fixed_crop.png 和 frame_15_fixed_crop.png
# 已生成增强数据：image_plot_16_rotate_90.png 和 frame_16_rotate_90.png
# 已生成增强数据：image_plot_16_rotate_180.png 和 frame_16_rotate_180.png
# 已生成增强数据：image_plot_16_flip_left_right.png 和 frame_16_flip_left_right.png
# 已生成增强数据：image_plot_16_flip_top_bottom.png 和 frame_16_flip_top_bottom.png
# 已生成增强数据：image_plot_16_translate.png 和 frame_16_translate.png
# 已生成增强数据：image_plot_16_scale.png 和 frame_16_scale.png
# 已生成增强数据：image_plot_16_brightness.png 和 frame_16_brightness.png
# 已生成增强数据：image_plot_16_contrast.png 和 frame_16_contrast.png
# 已生成增强数据：image_plot_16_gaussian_blur.png 和 frame_16_gaussian_blur.png
# 已生成增强数据：image_plot_16_noise.png 和 frame_16_noise.png
# 已生成增强数据：image_plot_16_fixed_crop.png 和 frame_16_fixed_crop.png
# 已生成增强数据：image_plot_17_rotate_90.png 和 frame_17_rotate_90.png
# 已生成增强数据：image_plot_17_rotate_180.png 和 frame_17_rotate_180.png
# 已生成增强数据：image_plot_17_flip_left_right.png 和 frame_17_flip_left_right.png
# 已生成增强数据：image_plot_17_flip_top_bottom.png 和 frame_17_flip_top_bottom.png
# 已生成增强数据：image_plot_17_translate.png 和 frame_17_translate.png
# 已生成增强数据：image_plot_17_scale.png 和 frame_17_scale.png
# 已生成增强数据：image_plot_17_brightness.png 和 frame_17_brightness.png
# 已生成增强数据：image_plot_17_contrast.png 和 frame_17_contrast.png
# 已生成增强数据：image_plot_17_gaussian_blur.png 和 frame_17_gaussian_blur.png
# 已生成增强数据：image_plot_17_noise.png 和 frame_17_noise.png
# 已生成增强数据：image_plot_17_fixed_crop.png 和 frame_17_fixed_crop.png
# 已生成增强数据：image_plot_18_rotate_90.png 和 frame_18_rotate_90.png
# 已生成增强数据：image_plot_18_rotate_180.png 和 frame_18_rotate_180.png
# 已生成增强数据：image_plot_18_flip_left_right.png 和 frame_18_flip_left_right.png
# 已生成增强数据：image_plot_18_flip_top_bottom.png 和 frame_18_flip_top_bottom.png
# 已生成增强数据：image_plot_18_translate.png 和 frame_18_translate.png
# 已生成增强数据：image_plot_18_scale.png 和 frame_18_scale.png
# 已生成增强数据：image_plot_18_brightness.png 和 frame_18_brightness.png
# 已生成增强数据：image_plot_18_contrast.png 和 frame_18_contrast.png
# 已生成增强数据：image_plot_18_gaussian_blur.png 和 frame_18_gaussian_blur.png
# 已生成增强数据：image_plot_18_noise.png 和 frame_18_noise.png
# 已生成增强数据：image_plot_18_fixed_crop.png 和 frame_18_fixed_crop.png
# 已生成增强数据：image_plot_19_rotate_90.png 和 frame_19_rotate_90.png
# 已生成增强数据：image_plot_19_rotate_180.png 和 frame_19_rotate_180.png
# 已生成增强数据：image_plot_19_flip_left_right.png 和 frame_19_flip_left_right.png
# 已生成增强数据：image_plot_19_flip_top_bottom.png 和 frame_19_flip_top_bottom.png
# 已生成增强数据：image_plot_19_translate.png 和 frame_19_translate.png
# 已生成增强数据：image_plot_19_scale.png 和 frame_19_scale.png
# 已生成增强数据：image_plot_19_brightness.png 和 frame_19_brightness.png
# 已生成增强数据：image_plot_19_contrast.png 和 frame_19_contrast.png
# 已生成增强数据：image_plot_19_gaussian_blur.png 和 frame_19_gaussian_blur.png
# 已生成增强数据：image_plot_19_noise.png 和 frame_19_noise.png
# 已生成增强数据：image_plot_19_fixed_crop.png 和 frame_19_fixed_crop.png
# 已生成增强数据：image_plot_2_rotate_90.png 和 frame_2_rotate_90.png
# 已生成增强数据：image_plot_2_rotate_180.png 和 frame_2_rotate_180.png
# 已生成增强数据：image_plot_2_flip_left_right.png 和 frame_2_flip_left_right.png
# 已生成增强数据：image_plot_2_flip_top_bottom.png 和 frame_2_flip_top_bottom.png
# 已生成增强数据：image_plot_2_translate.png 和 frame_2_translate.png
# 已生成增强数据：image_plot_2_scale.png 和 frame_2_scale.png
# 已生成增强数据：image_plot_2_brightness.png 和 frame_2_brightness.png
# 已生成增强数据：image_plot_2_contrast.png 和 frame_2_contrast.png
# 已生成增强数据：image_plot_2_gaussian_blur.png 和 frame_2_gaussian_blur.png
# 已生成增强数据：image_plot_2_noise.png 和 frame_2_noise.png
# 已生成增强数据：image_plot_2_fixed_crop.png 和 frame_2_fixed_crop.png
# 已生成增强数据：image_plot_20_rotate_90.png 和 frame_20_rotate_90.png
# 已生成增强数据：image_plot_20_rotate_180.png 和 frame_20_rotate_180.png
# 已生成增强数据：image_plot_20_flip_left_right.png 和 frame_20_flip_left_right.png
# 已生成增强数据：image_plot_20_flip_top_bottom.png 和 frame_20_flip_top_bottom.png
# 已生成增强数据：image_plot_20_translate.png 和 frame_20_translate.png
# 已生成增强数据：image_plot_20_scale.png 和 frame_20_scale.png
# 已生成增强数据：image_plot_20_brightness.png 和 frame_20_brightness.png
# 已生成增强数据：image_plot_20_contrast.png 和 frame_20_contrast.png
# 已生成增强数据：image_plot_20_gaussian_blur.png 和 frame_20_gaussian_blur.png
# 已生成增强数据：image_plot_20_noise.png 和 frame_20_noise.png
# 已生成增强数据：image_plot_20_fixed_crop.png 和 frame_20_fixed_crop.png
# 已生成增强数据：image_plot_21_rotate_90.png 和 frame_21_rotate_90.png
# 已生成增强数据：image_plot_21_rotate_180.png 和 frame_21_rotate_180.png
# 已生成增强数据：image_plot_21_flip_left_right.png 和 frame_21_flip_left_right.png
# 已生成增强数据：image_plot_21_flip_top_bottom.png 和 frame_21_flip_top_bottom.png
# 已生成增强数据：image_plot_21_translate.png 和 frame_21_translate.png
# 已生成增强数据：image_plot_21_scale.png 和 frame_21_scale.png
# 已生成增强数据：image_plot_21_brightness.png 和 frame_21_brightness.png
# 已生成增强数据：image_plot_21_contrast.png 和 frame_21_contrast.png
# 已生成增强数据：image_plot_21_gaussian_blur.png 和 frame_21_gaussian_blur.png
# 已生成增强数据：image_plot_21_noise.png 和 frame_21_noise.png
# 已生成增强数据：image_plot_21_fixed_crop.png 和 frame_21_fixed_crop.png
# 已生成增强数据：image_plot_22_rotate_90.png 和 frame_22_rotate_90.png
# 已生成增强数据：image_plot_22_rotate_180.png 和 frame_22_rotate_180.png
# 已生成增强数据：image_plot_22_flip_left_right.png 和 frame_22_flip_left_right.png
# 已生成增强数据：image_plot_22_flip_top_bottom.png 和 frame_22_flip_top_bottom.png
# 已生成增强数据：image_plot_22_translate.png 和 frame_22_translate.png
# 已生成增强数据：image_plot_22_scale.png 和 frame_22_scale.png
# 已生成增强数据：image_plot_22_brightness.png 和 frame_22_brightness.png
# 已生成增强数据：image_plot_22_contrast.png 和 frame_22_contrast.png
# 已生成增强数据：image_plot_22_gaussian_blur.png 和 frame_22_gaussian_blur.png
# 已生成增强数据：image_plot_22_noise.png 和 frame_22_noise.png
# 已生成增强数据：image_plot_22_fixed_crop.png 和 frame_22_fixed_crop.png
# 已生成增强数据：image_plot_220_rotate_90.png 和 frame_220_rotate_90.png
# 已生成增强数据：image_plot_220_rotate_180.png 和 frame_220_rotate_180.png
# 已生成增强数据：image_plot_220_flip_left_right.png 和 frame_220_flip_left_right.png
# 已生成增强数据：image_plot_220_flip_top_bottom.png 和 frame_220_flip_top_bottom.png
# 已生成增强数据：image_plot_220_translate.png 和 frame_220_translate.png
# 已生成增强数据：image_plot_220_scale.png 和 frame_220_scale.png
# 已生成增强数据：image_plot_220_brightness.png 和 frame_220_brightness.png
# 已生成增强数据：image_plot_220_contrast.png 和 frame_220_contrast.png
# 已生成增强数据：image_plot_220_gaussian_blur.png 和 frame_220_gaussian_blur.png
# 已生成增强数据：image_plot_220_noise.png 和 frame_220_noise.png
# 已生成增强数据：image_plot_220_fixed_crop.png 和 frame_220_fixed_crop.png
# 已生成增强数据：image_plot_221_rotate_90.png 和 frame_221_rotate_90.png
# 已生成增强数据：image_plot_221_rotate_180.png 和 frame_221_rotate_180.png
# 已生成增强数据：image_plot_221_flip_left_right.png 和 frame_221_flip_left_right.png
# 已生成增强数据：image_plot_221_flip_top_bottom.png 和 frame_221_flip_top_bottom.png
# 已生成增强数据：image_plot_221_translate.png 和 frame_221_translate.png
# 已生成增强数据：image_plot_221_scale.png 和 frame_221_scale.png
# 已生成增强数据：image_plot_221_brightness.png 和 frame_221_brightness.png
# 已生成增强数据：image_plot_221_contrast.png 和 frame_221_contrast.png
# 已生成增强数据：image_plot_221_gaussian_blur.png 和 frame_221_gaussian_blur.png
# 已生成增强数据：image_plot_221_noise.png 和 frame_221_noise.png
# 已生成增强数据：image_plot_221_fixed_crop.png 和 frame_221_fixed_crop.png
# 已生成增强数据：image_plot_222_rotate_90.png 和 frame_222_rotate_90.png
# 已生成增强数据：image_plot_222_rotate_180.png 和 frame_222_rotate_180.png
# 已生成增强数据：image_plot_222_flip_left_right.png 和 frame_222_flip_left_right.png
# 已生成增强数据：image_plot_222_flip_top_bottom.png 和 frame_222_flip_top_bottom.png
# 已生成增强数据：image_plot_222_translate.png 和 frame_222_translate.png
# 已生成增强数据：image_plot_222_scale.png 和 frame_222_scale.png
# 已生成增强数据：image_plot_222_brightness.png 和 frame_222_brightness.png
# 已生成增强数据：image_plot_222_contrast.png 和 frame_222_contrast.png
# 已生成增强数据：image_plot_222_gaussian_blur.png 和 frame_222_gaussian_blur.png
# 已生成增强数据：image_plot_222_noise.png 和 frame_222_noise.png
# 已生成增强数据：image_plot_222_fixed_crop.png 和 frame_222_fixed_crop.png
# 已生成增强数据：image_plot_223_rotate_90.png 和 frame_223_rotate_90.png
# 已生成增强数据：image_plot_223_rotate_180.png 和 frame_223_rotate_180.png
# 已生成增强数据：image_plot_223_flip_left_right.png 和 frame_223_flip_left_right.png
# 已生成增强数据：image_plot_223_flip_top_bottom.png 和 frame_223_flip_top_bottom.png
# 已生成增强数据：image_plot_223_translate.png 和 frame_223_translate.png
# 已生成增强数据：image_plot_223_scale.png 和 frame_223_scale.png
# 已生成增强数据：image_plot_223_brightness.png 和 frame_223_brightness.png
# 已生成增强数据：image_plot_223_contrast.png 和 frame_223_contrast.png
# 已生成增强数据：image_plot_223_gaussian_blur.png 和 frame_223_gaussian_blur.png
# 已生成增强数据：image_plot_223_noise.png 和 frame_223_noise.png
# 已生成增强数据：image_plot_223_fixed_crop.png 和 frame_223_fixed_crop.png
# 已生成增强数据：image_plot_224_rotate_90.png 和 frame_224_rotate_90.png
# 已生成增强数据：image_plot_224_rotate_180.png 和 frame_224_rotate_180.png
# 已生成增强数据：image_plot_224_flip_left_right.png 和 frame_224_flip_left_right.png
# 已生成增强数据：image_plot_224_flip_top_bottom.png 和 frame_224_flip_top_bottom.png
# 已生成增强数据：image_plot_224_translate.png 和 frame_224_translate.png
# 已生成增强数据：image_plot_224_scale.png 和 frame_224_scale.png
# 已生成增强数据：image_plot_224_brightness.png 和 frame_224_brightness.png
# 已生成增强数据：image_plot_224_contrast.png 和 frame_224_contrast.png
# 已生成增强数据：image_plot_224_gaussian_blur.png 和 frame_224_gaussian_blur.png
# 已生成增强数据：image_plot_224_noise.png 和 frame_224_noise.png
# 已生成增强数据：image_plot_224_fixed_crop.png 和 frame_224_fixed_crop.png
# 已生成增强数据：image_plot_225_rotate_90.png 和 frame_225_rotate_90.png
# 已生成增强数据：image_plot_225_rotate_180.png 和 frame_225_rotate_180.png
# 已生成增强数据：image_plot_225_flip_left_right.png 和 frame_225_flip_left_right.png
# 已生成增强数据：image_plot_225_flip_top_bottom.png 和 frame_225_flip_top_bottom.png
# 已生成增强数据：image_plot_225_translate.png 和 frame_225_translate.png
# 已生成增强数据：image_plot_225_scale.png 和 frame_225_scale.png
# 已生成增强数据：image_plot_225_brightness.png 和 frame_225_brightness.png
# 已生成增强数据：image_plot_225_contrast.png 和 frame_225_contrast.png
# 已生成增强数据：image_plot_225_gaussian_blur.png 和 frame_225_gaussian_blur.png
# 已生成增强数据：image_plot_225_noise.png 和 frame_225_noise.png
# 已生成增强数据：image_plot_225_fixed_crop.png 和 frame_225_fixed_crop.png
# 已生成增强数据：image_plot_226_rotate_90.png 和 frame_226_rotate_90.png
# 已生成增强数据：image_plot_226_rotate_180.png 和 frame_226_rotate_180.png
# 已生成增强数据：image_plot_226_flip_left_right.png 和 frame_226_flip_left_right.png
# 已生成增强数据：image_plot_226_flip_top_bottom.png 和 frame_226_flip_top_bottom.png
# 已生成增强数据：image_plot_226_translate.png 和 frame_226_translate.png
# 已生成增强数据：image_plot_226_scale.png 和 frame_226_scale.png
# 已生成增强数据：image_plot_226_brightness.png 和 frame_226_brightness.png
# 已生成增强数据：image_plot_226_contrast.png 和 frame_226_contrast.png
# 已生成增强数据：image_plot_226_gaussian_blur.png 和 frame_226_gaussian_blur.png
# 已生成增强数据：image_plot_226_noise.png 和 frame_226_noise.png
# 已生成增强数据：image_plot_226_fixed_crop.png 和 frame_226_fixed_crop.png
# 已生成增强数据：image_plot_227_rotate_90.png 和 frame_227_rotate_90.png
# 已生成增强数据：image_plot_227_rotate_180.png 和 frame_227_rotate_180.png
# 已生成增强数据：image_plot_227_flip_left_right.png 和 frame_227_flip_left_right.png
# 已生成增强数据：image_plot_227_flip_top_bottom.png 和 frame_227_flip_top_bottom.png
# 已生成增强数据：image_plot_227_translate.png 和 frame_227_translate.png
# 已生成增强数据：image_plot_227_scale.png 和 frame_227_scale.png
# 已生成增强数据：image_plot_227_brightness.png 和 frame_227_brightness.png
# 已生成增强数据：image_plot_227_contrast.png 和 frame_227_contrast.png
# 已生成增强数据：image_plot_227_gaussian_blur.png 和 frame_227_gaussian_blur.png
# 已生成增强数据：image_plot_227_noise.png 和 frame_227_noise.png
# 已生成增强数据：image_plot_227_fixed_crop.png 和 frame_227_fixed_crop.png
# 已生成增强数据：image_plot_228_rotate_90.png 和 frame_228_rotate_90.png
# 已生成增强数据：image_plot_228_rotate_180.png 和 frame_228_rotate_180.png
# 已生成增强数据：image_plot_228_flip_left_right.png 和 frame_228_flip_left_right.png
# 已生成增强数据：image_plot_228_flip_top_bottom.png 和 frame_228_flip_top_bottom.png
# 已生成增强数据：image_plot_228_translate.png 和 frame_228_translate.png
# 已生成增强数据：image_plot_228_scale.png 和 frame_228_scale.png
# 已生成增强数据：image_plot_228_brightness.png 和 frame_228_brightness.png
# 已生成增强数据：image_plot_228_contrast.png 和 frame_228_contrast.png
# 已生成增强数据：image_plot_228_gaussian_blur.png 和 frame_228_gaussian_blur.png
# 已生成增强数据：image_plot_228_noise.png 和 frame_228_noise.png
# 已生成增强数据：image_plot_228_fixed_crop.png 和 frame_228_fixed_crop.png
# 已生成增强数据：image_plot_229_rotate_90.png 和 frame_229_rotate_90.png
# 已生成增强数据：image_plot_229_rotate_180.png 和 frame_229_rotate_180.png
# 已生成增强数据：image_plot_229_flip_left_right.png 和 frame_229_flip_left_right.png
# 已生成增强数据：image_plot_229_flip_top_bottom.png 和 frame_229_flip_top_bottom.png
# 已生成增强数据：image_plot_229_translate.png 和 frame_229_translate.png
# 已生成增强数据：image_plot_229_scale.png 和 frame_229_scale.png
# 已生成增强数据：image_plot_229_brightness.png 和 frame_229_brightness.png
# 已生成增强数据：image_plot_229_contrast.png 和 frame_229_contrast.png
# 已生成增强数据：image_plot_229_gaussian_blur.png 和 frame_229_gaussian_blur.png
# 已生成增强数据：image_plot_229_noise.png 和 frame_229_noise.png
# 已生成增强数据：image_plot_229_fixed_crop.png 和 frame_229_fixed_crop.png
# 已生成增强数据：image_plot_23_rotate_90.png 和 frame_23_rotate_90.png
# 已生成增强数据：image_plot_23_rotate_180.png 和 frame_23_rotate_180.png
# 已生成增强数据：image_plot_23_flip_left_right.png 和 frame_23_flip_left_right.png
# 已生成增强数据：image_plot_23_flip_top_bottom.png 和 frame_23_flip_top_bottom.png
# 已生成增强数据：image_plot_23_translate.png 和 frame_23_translate.png
# 已生成增强数据：image_plot_23_scale.png 和 frame_23_scale.png
# 已生成增强数据：image_plot_23_brightness.png 和 frame_23_brightness.png
# 已生成增强数据：image_plot_23_contrast.png 和 frame_23_contrast.png
# 已生成增强数据：image_plot_23_gaussian_blur.png 和 frame_23_gaussian_blur.png
# 已生成增强数据：image_plot_23_noise.png 和 frame_23_noise.png
# 已生成增强数据：image_plot_23_fixed_crop.png 和 frame_23_fixed_crop.png
# 已生成增强数据：image_plot_230_rotate_90.png 和 frame_230_rotate_90.png
# 已生成增强数据：image_plot_230_rotate_180.png 和 frame_230_rotate_180.png
# 已生成增强数据：image_plot_230_flip_left_right.png 和 frame_230_flip_left_right.png
# 已生成增强数据：image_plot_230_flip_top_bottom.png 和 frame_230_flip_top_bottom.png
# 已生成增强数据：image_plot_230_translate.png 和 frame_230_translate.png
# 已生成增强数据：image_plot_230_scale.png 和 frame_230_scale.png
# 已生成增强数据：image_plot_230_brightness.png 和 frame_230_brightness.png
# 已生成增强数据：image_plot_230_contrast.png 和 frame_230_contrast.png
# 已生成增强数据：image_plot_230_gaussian_blur.png 和 frame_230_gaussian_blur.png
# 已生成增强数据：image_plot_230_noise.png 和 frame_230_noise.png
# 已生成增强数据：image_plot_230_fixed_crop.png 和 frame_230_fixed_crop.png
# 已生成增强数据：image_plot_231_rotate_90.png 和 frame_231_rotate_90.png
# 已生成增强数据：image_plot_231_rotate_180.png 和 frame_231_rotate_180.png
# 已生成增强数据：image_plot_231_flip_left_right.png 和 frame_231_flip_left_right.png
# 已生成增强数据：image_plot_231_flip_top_bottom.png 和 frame_231_flip_top_bottom.png
# 已生成增强数据：image_plot_231_translate.png 和 frame_231_translate.png
# 已生成增强数据：image_plot_231_scale.png 和 frame_231_scale.png
# 已生成增强数据：image_plot_231_brightness.png 和 frame_231_brightness.png
# 已生成增强数据：image_plot_231_contrast.png 和 frame_231_contrast.png
# 已生成增强数据：image_plot_231_gaussian_blur.png 和 frame_231_gaussian_blur.png
# 已生成增强数据：image_plot_231_noise.png 和 frame_231_noise.png
# 已生成增强数据：image_plot_231_fixed_crop.png 和 frame_231_fixed_crop.png
# 已生成增强数据：image_plot_232_rotate_90.png 和 frame_232_rotate_90.png
# 已生成增强数据：image_plot_232_rotate_180.png 和 frame_232_rotate_180.png
# 已生成增强数据：image_plot_232_flip_left_right.png 和 frame_232_flip_left_right.png
# 已生成增强数据：image_plot_232_flip_top_bottom.png 和 frame_232_flip_top_bottom.png
# 已生成增强数据：image_plot_232_translate.png 和 frame_232_translate.png
# 已生成增强数据：image_plot_232_scale.png 和 frame_232_scale.png
# 已生成增强数据：image_plot_232_brightness.png 和 frame_232_brightness.png
# 已生成增强数据：image_plot_232_contrast.png 和 frame_232_contrast.png
# 已生成增强数据：image_plot_232_gaussian_blur.png 和 frame_232_gaussian_blur.png
# 已生成增强数据：image_plot_232_noise.png 和 frame_232_noise.png
# 已生成增强数据：image_plot_232_fixed_crop.png 和 frame_232_fixed_crop.png
# 已生成增强数据：image_plot_233_rotate_90.png 和 frame_233_rotate_90.png
# 已生成增强数据：image_plot_233_rotate_180.png 和 frame_233_rotate_180.png
# 已生成增强数据：image_plot_233_flip_left_right.png 和 frame_233_flip_left_right.png
# 已生成增强数据：image_plot_233_flip_top_bottom.png 和 frame_233_flip_top_bottom.png
# 已生成增强数据：image_plot_233_translate.png 和 frame_233_translate.png
# 已生成增强数据：image_plot_233_scale.png 和 frame_233_scale.png
# 已生成增强数据：image_plot_233_brightness.png 和 frame_233_brightness.png
# 已生成增强数据：image_plot_233_contrast.png 和 frame_233_contrast.png
# 已生成增强数据：image_plot_233_gaussian_blur.png 和 frame_233_gaussian_blur.png
# 已生成增强数据：image_plot_233_noise.png 和 frame_233_noise.png
# 已生成增强数据：image_plot_233_fixed_crop.png 和 frame_233_fixed_crop.png
# 已生成增强数据：image_plot_234_rotate_90.png 和 frame_234_rotate_90.png
# 已生成增强数据：image_plot_234_rotate_180.png 和 frame_234_rotate_180.png
# 已生成增强数据：image_plot_234_flip_left_right.png 和 frame_234_flip_left_right.png
# 已生成增强数据：image_plot_234_flip_top_bottom.png 和 frame_234_flip_top_bottom.png
# 已生成增强数据：image_plot_234_translate.png 和 frame_234_translate.png
# 已生成增强数据：image_plot_234_scale.png 和 frame_234_scale.png
# 已生成增强数据：image_plot_234_brightness.png 和 frame_234_brightness.png
# 已生成增强数据：image_plot_234_contrast.png 和 frame_234_contrast.png
# 已生成增强数据：image_plot_234_gaussian_blur.png 和 frame_234_gaussian_blur.png
# 已生成增强数据：image_plot_234_noise.png 和 frame_234_noise.png
# 已生成增强数据：image_plot_234_fixed_crop.png 和 frame_234_fixed_crop.png
# 已生成增强数据：image_plot_235_rotate_90.png 和 frame_235_rotate_90.png
# 已生成增强数据：image_plot_235_rotate_180.png 和 frame_235_rotate_180.png
# 已生成增强数据：image_plot_235_flip_left_right.png 和 frame_235_flip_left_right.png
# 已生成增强数据：image_plot_235_flip_top_bottom.png 和 frame_235_flip_top_bottom.png
# 已生成增强数据：image_plot_235_translate.png 和 frame_235_translate.png
# 已生成增强数据：image_plot_235_scale.png 和 frame_235_scale.png
# 已生成增强数据：image_plot_235_brightness.png 和 frame_235_brightness.png
# 已生成增强数据：image_plot_235_contrast.png 和 frame_235_contrast.png
# 已生成增强数据：image_plot_235_gaussian_blur.png 和 frame_235_gaussian_blur.png
# 已生成增强数据：image_plot_235_noise.png 和 frame_235_noise.png
# 已生成增强数据：image_plot_235_fixed_crop.png 和 frame_235_fixed_crop.png
# 已生成增强数据：image_plot_236_rotate_90.png 和 frame_236_rotate_90.png
# 已生成增强数据：image_plot_236_rotate_180.png 和 frame_236_rotate_180.png
# 已生成增强数据：image_plot_236_flip_left_right.png 和 frame_236_flip_left_right.png
# 已生成增强数据：image_plot_236_flip_top_bottom.png 和 frame_236_flip_top_bottom.png
# 已生成增强数据：image_plot_236_translate.png 和 frame_236_translate.png
# 已生成增强数据：image_plot_236_scale.png 和 frame_236_scale.png
# 已生成增强数据：image_plot_236_brightness.png 和 frame_236_brightness.png
# 已生成增强数据：image_plot_236_contrast.png 和 frame_236_contrast.png
# 已生成增强数据：image_plot_236_gaussian_blur.png 和 frame_236_gaussian_blur.png
# 已生成增强数据：image_plot_236_noise.png 和 frame_236_noise.png
# 已生成增强数据：image_plot_236_fixed_crop.png 和 frame_236_fixed_crop.png
# 已生成增强数据：image_plot_237_rotate_90.png 和 frame_237_rotate_90.png
# 已生成增强数据：image_plot_237_rotate_180.png 和 frame_237_rotate_180.png
# 已生成增强数据：image_plot_237_flip_left_right.png 和 frame_237_flip_left_right.png
# 已生成增强数据：image_plot_237_flip_top_bottom.png 和 frame_237_flip_top_bottom.png
# 已生成增强数据：image_plot_237_translate.png 和 frame_237_translate.png
# 已生成增强数据：image_plot_237_scale.png 和 frame_237_scale.png
# 已生成增强数据：image_plot_237_brightness.png 和 frame_237_brightness.png
# 已生成增强数据：image_plot_237_contrast.png 和 frame_237_contrast.png
# 已生成增强数据：image_plot_237_gaussian_blur.png 和 frame_237_gaussian_blur.png
# 已生成增强数据：image_plot_237_noise.png 和 frame_237_noise.png
# 已生成增强数据：image_plot_237_fixed_crop.png 和 frame_237_fixed_crop.png
# 已生成增强数据：image_plot_238_rotate_90.png 和 frame_238_rotate_90.png
# 已生成增强数据：image_plot_238_rotate_180.png 和 frame_238_rotate_180.png
# 已生成增强数据：image_plot_238_flip_left_right.png 和 frame_238_flip_left_right.png
# 已生成增强数据：image_plot_238_flip_top_bottom.png 和 frame_238_flip_top_bottom.png
# 已生成增强数据：image_plot_238_translate.png 和 frame_238_translate.png
# 已生成增强数据：image_plot_238_scale.png 和 frame_238_scale.png
# 已生成增强数据：image_plot_238_brightness.png 和 frame_238_brightness.png
# 已生成增强数据：image_plot_238_contrast.png 和 frame_238_contrast.png
# 已生成增强数据：image_plot_238_gaussian_blur.png 和 frame_238_gaussian_blur.png
# 已生成增强数据：image_plot_238_noise.png 和 frame_238_noise.png
# 已生成增强数据：image_plot_238_fixed_crop.png 和 frame_238_fixed_crop.png
# 已生成增强数据：image_plot_239_rotate_90.png 和 frame_239_rotate_90.png
# 已生成增强数据：image_plot_239_rotate_180.png 和 frame_239_rotate_180.png
# 已生成增强数据：image_plot_239_flip_left_right.png 和 frame_239_flip_left_right.png
# 已生成增强数据：image_plot_239_flip_top_bottom.png 和 frame_239_flip_top_bottom.png
# 已生成增强数据：image_plot_239_translate.png 和 frame_239_translate.png
# 已生成增强数据：image_plot_239_scale.png 和 frame_239_scale.png
# 已生成增强数据：image_plot_239_brightness.png 和 frame_239_brightness.png
# 已生成增强数据：image_plot_239_contrast.png 和 frame_239_contrast.png
# 已生成增强数据：image_plot_239_gaussian_blur.png 和 frame_239_gaussian_blur.png
# 已生成增强数据：image_plot_239_noise.png 和 frame_239_noise.png
# 已生成增强数据：image_plot_239_fixed_crop.png 和 frame_239_fixed_crop.png
# 已生成增强数据：image_plot_24_rotate_90.png 和 frame_24_rotate_90.png
# 已生成增强数据：image_plot_24_rotate_180.png 和 frame_24_rotate_180.png
# 已生成增强数据：image_plot_24_flip_left_right.png 和 frame_24_flip_left_right.png
# 已生成增强数据：image_plot_24_flip_top_bottom.png 和 frame_24_flip_top_bottom.png
# 已生成增强数据：image_plot_24_translate.png 和 frame_24_translate.png
# 已生成增强数据：image_plot_24_scale.png 和 frame_24_scale.png
# 已生成增强数据：image_plot_24_brightness.png 和 frame_24_brightness.png
# 已生成增强数据：image_plot_24_contrast.png 和 frame_24_contrast.png
# 已生成增强数据：image_plot_24_gaussian_blur.png 和 frame_24_gaussian_blur.png
# 已生成增强数据：image_plot_24_noise.png 和 frame_24_noise.png
# 已生成增强数据：image_plot_24_fixed_crop.png 和 frame_24_fixed_crop.png
# 已生成增强数据：image_plot_240_rotate_90.png 和 frame_240_rotate_90.png
# 已生成增强数据：image_plot_240_rotate_180.png 和 frame_240_rotate_180.png
# 已生成增强数据：image_plot_240_flip_left_right.png 和 frame_240_flip_left_right.png
# 已生成增强数据：image_plot_240_flip_top_bottom.png 和 frame_240_flip_top_bottom.png
# 已生成增强数据：image_plot_240_translate.png 和 frame_240_translate.png
# 已生成增强数据：image_plot_240_scale.png 和 frame_240_scale.png
# 已生成增强数据：image_plot_240_brightness.png 和 frame_240_brightness.png
# 已生成增强数据：image_plot_240_contrast.png 和 frame_240_contrast.png
# 已生成增强数据：image_plot_240_gaussian_blur.png 和 frame_240_gaussian_blur.png
# 已生成增强数据：image_plot_240_noise.png 和 frame_240_noise.png
# 已生成增强数据：image_plot_240_fixed_crop.png 和 frame_240_fixed_crop.png
# 已生成增强数据：image_plot_241_rotate_90.png 和 frame_241_rotate_90.png
# 已生成增强数据：image_plot_241_rotate_180.png 和 frame_241_rotate_180.png
# 已生成增强数据：image_plot_241_flip_left_right.png 和 frame_241_flip_left_right.png
# 已生成增强数据：image_plot_241_flip_top_bottom.png 和 frame_241_flip_top_bottom.png
# 已生成增强数据：image_plot_241_translate.png 和 frame_241_translate.png
# 已生成增强数据：image_plot_241_scale.png 和 frame_241_scale.png
# 已生成增强数据：image_plot_241_brightness.png 和 frame_241_brightness.png
# 已生成增强数据：image_plot_241_contrast.png 和 frame_241_contrast.png
# 已生成增强数据：image_plot_241_gaussian_blur.png 和 frame_241_gaussian_blur.png
# 已生成增强数据：image_plot_241_noise.png 和 frame_241_noise.png
# 已生成增强数据：image_plot_241_fixed_crop.png 和 frame_241_fixed_crop.png
# 已生成增强数据：image_plot_242_rotate_90.png 和 frame_242_rotate_90.png
# 已生成增强数据：image_plot_242_rotate_180.png 和 frame_242_rotate_180.png
# 已生成增强数据：image_plot_242_flip_left_right.png 和 frame_242_flip_left_right.png
# 已生成增强数据：image_plot_242_flip_top_bottom.png 和 frame_242_flip_top_bottom.png
# 已生成增强数据：image_plot_242_translate.png 和 frame_242_translate.png
# 已生成增强数据：image_plot_242_scale.png 和 frame_242_scale.png
# 已生成增强数据：image_plot_242_brightness.png 和 frame_242_brightness.png
# 已生成增强数据：image_plot_242_contrast.png 和 frame_242_contrast.png
# 已生成增强数据：image_plot_242_gaussian_blur.png 和 frame_242_gaussian_blur.png
# 已生成增强数据：image_plot_242_noise.png 和 frame_242_noise.png
# 已生成增强数据：image_plot_242_fixed_crop.png 和 frame_242_fixed_crop.png
# 已生成增强数据：image_plot_243_rotate_90.png 和 frame_243_rotate_90.png
# 已生成增强数据：image_plot_243_rotate_180.png 和 frame_243_rotate_180.png
# 已生成增强数据：image_plot_243_flip_left_right.png 和 frame_243_flip_left_right.png
# 已生成增强数据：image_plot_243_flip_top_bottom.png 和 frame_243_flip_top_bottom.png
# 已生成增强数据：image_plot_243_translate.png 和 frame_243_translate.png
# 已生成增强数据：image_plot_243_scale.png 和 frame_243_scale.png
# 已生成增强数据：image_plot_243_brightness.png 和 frame_243_brightness.png
# 已生成增强数据：image_plot_243_contrast.png 和 frame_243_contrast.png
# 已生成增强数据：image_plot_243_gaussian_blur.png 和 frame_243_gaussian_blur.png
# 已生成增强数据：image_plot_243_noise.png 和 frame_243_noise.png
# 已生成增强数据：image_plot_243_fixed_crop.png 和 frame_243_fixed_crop.png
# 已生成增强数据：image_plot_244_rotate_90.png 和 frame_244_rotate_90.png
# 已生成增强数据：image_plot_244_rotate_180.png 和 frame_244_rotate_180.png
# 已生成增强数据：image_plot_244_flip_left_right.png 和 frame_244_flip_left_right.png
# 已生成增强数据：image_plot_244_flip_top_bottom.png 和 frame_244_flip_top_bottom.png
# 已生成增强数据：image_plot_244_translate.png 和 frame_244_translate.png
# 已生成增强数据：image_plot_244_scale.png 和 frame_244_scale.png
# 已生成增强数据：image_plot_244_brightness.png 和 frame_244_brightness.png
# 已生成增强数据：image_plot_244_contrast.png 和 frame_244_contrast.png
# 已生成增强数据：image_plot_244_gaussian_blur.png 和 frame_244_gaussian_blur.png
# 已生成增强数据：image_plot_244_noise.png 和 frame_244_noise.png
# 已生成增强数据：image_plot_244_fixed_crop.png 和 frame_244_fixed_crop.png
# 已生成增强数据：image_plot_245_rotate_90.png 和 frame_245_rotate_90.png
# 已生成增强数据：image_plot_245_rotate_180.png 和 frame_245_rotate_180.png
# 已生成增强数据：image_plot_245_flip_left_right.png 和 frame_245_flip_left_right.png
# 已生成增强数据：image_plot_245_flip_top_bottom.png 和 frame_245_flip_top_bottom.png
# 已生成增强数据：image_plot_245_translate.png 和 frame_245_translate.png
# 已生成增强数据：image_plot_245_scale.png 和 frame_245_scale.png
# 已生成增强数据：image_plot_245_brightness.png 和 frame_245_brightness.png
# 已生成增强数据：image_plot_245_contrast.png 和 frame_245_contrast.png
# 已生成增强数据：image_plot_245_gaussian_blur.png 和 frame_245_gaussian_blur.png
# 已生成增强数据：image_plot_245_noise.png 和 frame_245_noise.png
# 已生成增强数据：image_plot_245_fixed_crop.png 和 frame_245_fixed_crop.png
# 已生成增强数据：image_plot_246_rotate_90.png 和 frame_246_rotate_90.png
# 已生成增强数据：image_plot_246_rotate_180.png 和 frame_246_rotate_180.png
# 已生成增强数据：image_plot_246_flip_left_right.png 和 frame_246_flip_left_right.png
# 已生成增强数据：image_plot_246_flip_top_bottom.png 和 frame_246_flip_top_bottom.png
# 已生成增强数据：image_plot_246_translate.png 和 frame_246_translate.png
# 已生成增强数据：image_plot_246_scale.png 和 frame_246_scale.png
# 已生成增强数据：image_plot_246_brightness.png 和 frame_246_brightness.png
# 已生成增强数据：image_plot_246_contrast.png 和 frame_246_contrast.png
# 已生成增强数据：image_plot_246_gaussian_blur.png 和 frame_246_gaussian_blur.png
# 已生成增强数据：image_plot_246_noise.png 和 frame_246_noise.png
# 已生成增强数据：image_plot_246_fixed_crop.png 和 frame_246_fixed_crop.png
# 已生成增强数据：image_plot_247_rotate_90.png 和 frame_247_rotate_90.png
# 已生成增强数据：image_plot_247_rotate_180.png 和 frame_247_rotate_180.png
# 已生成增强数据：image_plot_247_flip_left_right.png 和 frame_247_flip_left_right.png
# 已生成增强数据：image_plot_247_flip_top_bottom.png 和 frame_247_flip_top_bottom.png
# 已生成增强数据：image_plot_247_translate.png 和 frame_247_translate.png
# 已生成增强数据：image_plot_247_scale.png 和 frame_247_scale.png
# 已生成增强数据：image_plot_247_brightness.png 和 frame_247_brightness.png
# 已生成增强数据：image_plot_247_contrast.png 和 frame_247_contrast.png
# 已生成增强数据：image_plot_247_gaussian_blur.png 和 frame_247_gaussian_blur.png
# 已生成增强数据：image_plot_247_noise.png 和 frame_247_noise.png
# 已生成增强数据：image_plot_247_fixed_crop.png 和 frame_247_fixed_crop.png
# 已生成增强数据：image_plot_248_rotate_90.png 和 frame_248_rotate_90.png
# 已生成增强数据：image_plot_248_rotate_180.png 和 frame_248_rotate_180.png
# 已生成增强数据：image_plot_248_flip_left_right.png 和 frame_248_flip_left_right.png
# 已生成增强数据：image_plot_248_flip_top_bottom.png 和 frame_248_flip_top_bottom.png
# 已生成增强数据：image_plot_248_translate.png 和 frame_248_translate.png
# 已生成增强数据：image_plot_248_scale.png 和 frame_248_scale.png
# 已生成增强数据：image_plot_248_brightness.png 和 frame_248_brightness.png
# 已生成增强数据：image_plot_248_contrast.png 和 frame_248_contrast.png
# 已生成增强数据：image_plot_248_gaussian_blur.png 和 frame_248_gaussian_blur.png
# 已生成增强数据：image_plot_248_noise.png 和 frame_248_noise.png
# 已生成增强数据：image_plot_248_fixed_crop.png 和 frame_248_fixed_crop.png
# 已生成增强数据：image_plot_249_rotate_90.png 和 frame_249_rotate_90.png
# 已生成增强数据：image_plot_249_rotate_180.png 和 frame_249_rotate_180.png
# 已生成增强数据：image_plot_249_flip_left_right.png 和 frame_249_flip_left_right.png
# 已生成增强数据：image_plot_249_flip_top_bottom.png 和 frame_249_flip_top_bottom.png
# 已生成增强数据：image_plot_249_translate.png 和 frame_249_translate.png
# 已生成增强数据：image_plot_249_scale.png 和 frame_249_scale.png
# 已生成增强数据：image_plot_249_brightness.png 和 frame_249_brightness.png
# 已生成增强数据：image_plot_249_contrast.png 和 frame_249_contrast.png
# 已生成增强数据：image_plot_249_gaussian_blur.png 和 frame_249_gaussian_blur.png
# ...
# 已生成增强数据：image_plot_78_noise.png 和 frame_78_noise.png
# 已生成增强数据：image_plot_78_fixed_crop.png 和 frame_78_fixed_crop.png
# 已生成增强数据：image_plot_79_rotate_90.png 和 frame_79_rotate_90.png
# 已生成增强数据：image_plot_79_rotate_180.png 和 frame_79_rotate_180.png
# 已生成增强数据：image_plot_79_flip_left_right.png 和 frame_79_flip_left_right.png
# 已生成增强数据：image_plot_79_flip_top_bottom.png 和 frame_79_flip_top_bottom.png
# 已生成增强数据：image_plot_79_translate.png 和 frame_79_translate.png
# 已生成增强数据：image_plot_79_scale.png 和 frame_79_scale.png
# 已生成增强数据：image_plot_79_brightness.png 和 frame_79_brightness.png
# 已生成增强数据：image_plot_79_contrast.png 和 frame_79_contrast.png
# 已生成增强数据：image_plot_79_gaussian_blur.png 和 frame_79_gaussian_blur.png
# 已生成增强数据：image_plot_79_noise.png 和 frame_79_noise.png
# 已生成增强数据：image_plot_79_fixed_crop.png 和 frame_79_fixed_crop.png
# 已生成增强数据：image_plot_8_rotate_90.png 和 frame_8_rotate_90.png
# 已生成增强数据：image_plot_8_rotate_180.png 和 frame_8_rotate_180.png
# 已生成增强数据：image_plot_8_flip_left_right.png 和 frame_8_flip_left_right.png
# 已生成增强数据：image_plot_8_flip_top_bottom.png 和 frame_8_flip_top_bottom.png
# 已生成增强数据：image_plot_8_translate.png 和 frame_8_translate.png
# 已生成增强数据：image_plot_8_scale.png 和 frame_8_scale.png
# 已生成增强数据：image_plot_8_brightness.png 和 frame_8_brightness.png
# 已生成增强数据：image_plot_8_contrast.png 和 frame_8_contrast.png
# 已生成增强数据：image_plot_8_gaussian_blur.png 和 frame_8_gaussian_blur.png
# 已生成增强数据：image_plot_8_noise.png 和 frame_8_noise.png
# 已生成增强数据：image_plot_8_fixed_crop.png 和 frame_8_fixed_crop.png
# 已生成增强数据：image_plot_80_rotate_90.png 和 frame_80_rotate_90.png
# 已生成增强数据：image_plot_80_rotate_180.png 和 frame_80_rotate_180.png
# 已生成增强数据：image_plot_80_flip_left_right.png 和 frame_80_flip_left_right.png
# 已生成增强数据：image_plot_80_flip_top_bottom.png 和 frame_80_flip_top_bottom.png
# 已生成增强数据：image_plot_80_translate.png 和 frame_80_translate.png
# 已生成增强数据：image_plot_80_scale.png 和 frame_80_scale.png
# 已生成增强数据：image_plot_80_brightness.png 和 frame_80_brightness.png
# 已生成增强数据：image_plot_80_contrast.png 和 frame_80_contrast.png
# 已生成增强数据：image_plot_80_gaussian_blur.png 和 frame_80_gaussian_blur.png
# 已生成增强数据：image_plot_80_noise.png 和 frame_80_noise.png
# 已生成增强数据：image_plot_80_fixed_crop.png 和 frame_80_fixed_crop.png
# 已生成增强数据：image_plot_81_rotate_90.png 和 frame_81_rotate_90.png
# 已生成增强数据：image_plot_81_rotate_180.png 和 frame_81_rotate_180.png
# 已生成增强数据：image_plot_81_flip_left_right.png 和 frame_81_flip_left_right.png
# 已生成增强数据：image_plot_81_flip_top_bottom.png 和 frame_81_flip_top_bottom.png
# 已生成增强数据：image_plot_81_translate.png 和 frame_81_translate.png
# 已生成增强数据：image_plot_81_scale.png 和 frame_81_scale.png
# 已生成增强数据：image_plot_81_brightness.png 和 frame_81_brightness.png
# 已生成增强数据：image_plot_81_contrast.png 和 frame_81_contrast.png
# 已生成增强数据：image_plot_81_gaussian_blur.png 和 frame_81_gaussian_blur.png
# 已生成增强数据：image_plot_81_noise.png 和 frame_81_noise.png
# 已生成增强数据：image_plot_81_fixed_crop.png 和 frame_81_fixed_crop.png
# 已生成增强数据：image_plot_82_rotate_90.png 和 frame_82_rotate_90.png
# 已生成增强数据：image_plot_82_rotate_180.png 和 frame_82_rotate_180.png
# 已生成增强数据：image_plot_82_flip_left_right.png 和 frame_82_flip_left_right.png
# 已生成增强数据：image_plot_82_flip_top_bottom.png 和 frame_82_flip_top_bottom.png
# 已生成增强数据：image_plot_82_translate.png 和 frame_82_translate.png
# 已生成增强数据：image_plot_82_scale.png 和 frame_82_scale.png
# 已生成增强数据：image_plot_82_brightness.png 和 frame_82_brightness.png
# 已生成增强数据：image_plot_82_contrast.png 和 frame_82_contrast.png
# 已生成增强数据：image_plot_82_gaussian_blur.png 和 frame_82_gaussian_blur.png
# 已生成增强数据：image_plot_82_noise.png 和 frame_82_noise.png
# 已生成增强数据：image_plot_82_fixed_crop.png 和 frame_82_fixed_crop.png
# 已生成增强数据：image_plot_83_rotate_90.png 和 frame_83_rotate_90.png
# 已生成增强数据：image_plot_83_rotate_180.png 和 frame_83_rotate_180.png
# 已生成增强数据：image_plot_83_flip_left_right.png 和 frame_83_flip_left_right.png
# 已生成增强数据：image_plot_83_flip_top_bottom.png 和 frame_83_flip_top_bottom.png
# 已生成增强数据：image_plot_83_translate.png 和 frame_83_translate.png
# 已生成增强数据：image_plot_83_scale.png 和 frame_83_scale.png
# 已生成增强数据：image_plot_83_brightness.png 和 frame_83_brightness.png
# 已生成增强数据：image_plot_83_contrast.png 和 frame_83_contrast.png
# 已生成增强数据：image_plot_83_gaussian_blur.png 和 frame_83_gaussian_blur.png
# 已生成增强数据：image_plot_83_noise.png 和 frame_83_noise.png
# 已生成增强数据：image_plot_83_fixed_crop.png 和 frame_83_fixed_crop.png
# 已生成增强数据：image_plot_84_rotate_90.png 和 frame_84_rotate_90.png
# 已生成增强数据：image_plot_84_rotate_180.png 和 frame_84_rotate_180.png
# 已生成增强数据：image_plot_84_flip_left_right.png 和 frame_84_flip_left_right.png
# 已生成增强数据：image_plot_84_flip_top_bottom.png 和 frame_84_flip_top_bottom.png
# 已生成增强数据：image_plot_84_translate.png 和 frame_84_translate.png
# 已生成增强数据：image_plot_84_scale.png 和 frame_84_scale.png
# 已生成增强数据：image_plot_84_brightness.png 和 frame_84_brightness.png
# 已生成增强数据：image_plot_84_contrast.png 和 frame_84_contrast.png
# 已生成增强数据：image_plot_84_gaussian_blur.png 和 frame_84_gaussian_blur.png
# 已生成增强数据：image_plot_84_noise.png 和 frame_84_noise.png
# 已生成增强数据：image_plot_84_fixed_crop.png 和 frame_84_fixed_crop.png
# 已生成增强数据：image_plot_85_rotate_90.png 和 frame_85_rotate_90.png
# 已生成增强数据：image_plot_85_rotate_180.png 和 frame_85_rotate_180.png
# 已生成增强数据：image_plot_85_flip_left_right.png 和 frame_85_flip_left_right.png
# 已生成增强数据：image_plot_85_flip_top_bottom.png 和 frame_85_flip_top_bottom.png
# 已生成增强数据：image_plot_85_translate.png 和 frame_85_translate.png
# 已生成增强数据：image_plot_85_scale.png 和 frame_85_scale.png
# 已生成增强数据：image_plot_85_brightness.png 和 frame_85_brightness.png
# 已生成增强数据：image_plot_85_contrast.png 和 frame_85_contrast.png
# 已生成增强数据：image_plot_85_gaussian_blur.png 和 frame_85_gaussian_blur.png
# 已生成增强数据：image_plot_85_noise.png 和 frame_85_noise.png
# 已生成增强数据：image_plot_85_fixed_crop.png 和 frame_85_fixed_crop.png
# 已生成增强数据：image_plot_86_rotate_90.png 和 frame_86_rotate_90.png
# 已生成增强数据：image_plot_86_rotate_180.png 和 frame_86_rotate_180.png
# 已生成增强数据：image_plot_86_flip_left_right.png 和 frame_86_flip_left_right.png
# 已生成增强数据：image_plot_86_flip_top_bottom.png 和 frame_86_flip_top_bottom.png
# 已生成增强数据：image_plot_86_translate.png 和 frame_86_translate.png
# 已生成增强数据：image_plot_86_scale.png 和 frame_86_scale.png
# 已生成增强数据：image_plot_86_brightness.png 和 frame_86_brightness.png
# 已生成增强数据：image_plot_86_contrast.png 和 frame_86_contrast.png
# 已生成增强数据：image_plot_86_gaussian_blur.png 和 frame_86_gaussian_blur.png
# 已生成增强数据：image_plot_86_noise.png 和 frame_86_noise.png
# 已生成增强数据：image_plot_86_fixed_crop.png 和 frame_86_fixed_crop.png
# 已生成增强数据：image_plot_87_rotate_90.png 和 frame_87_rotate_90.png
# 已生成增强数据：image_plot_87_rotate_180.png 和 frame_87_rotate_180.png
# 已生成增强数据：image_plot_87_flip_left_right.png 和 frame_87_flip_left_right.png
# 已生成增强数据：image_plot_87_flip_top_bottom.png 和 frame_87_flip_top_bottom.png
# 已生成增强数据：image_plot_87_translate.png 和 frame_87_translate.png
# 已生成增强数据：image_plot_87_scale.png 和 frame_87_scale.png
# 已生成增强数据：image_plot_87_brightness.png 和 frame_87_brightness.png
# 已生成增强数据：image_plot_87_contrast.png 和 frame_87_contrast.png
# 已生成增强数据：image_plot_87_gaussian_blur.png 和 frame_87_gaussian_blur.png
# 已生成增强数据：image_plot_87_noise.png 和 frame_87_noise.png
# 已生成增强数据：image_plot_87_fixed_crop.png 和 frame_87_fixed_crop.png
# 已生成增强数据：image_plot_88_rotate_90.png 和 frame_88_rotate_90.png
# 已生成增强数据：image_plot_88_rotate_180.png 和 frame_88_rotate_180.png
# 已生成增强数据：image_plot_88_flip_left_right.png 和 frame_88_flip_left_right.png
# 已生成增强数据：image_plot_88_flip_top_bottom.png 和 frame_88_flip_top_bottom.png
# 已生成增强数据：image_plot_88_translate.png 和 frame_88_translate.png
# 已生成增强数据：image_plot_88_scale.png 和 frame_88_scale.png
# 已生成增强数据：image_plot_88_brightness.png 和 frame_88_brightness.png
# 已生成增强数据：image_plot_88_contrast.png 和 frame_88_contrast.png
# 已生成增强数据：image_plot_88_gaussian_blur.png 和 frame_88_gaussian_blur.png
# 已生成增强数据：image_plot_88_noise.png 和 frame_88_noise.png
# 已生成增强数据：image_plot_88_fixed_crop.png 和 frame_88_fixed_crop.png
# 已生成增强数据：image_plot_89_rotate_90.png 和 frame_89_rotate_90.png
# 已生成增强数据：image_plot_89_rotate_180.png 和 frame_89_rotate_180.png
# 已生成增强数据：image_plot_89_flip_left_right.png 和 frame_89_flip_left_right.png
# 已生成增强数据：image_plot_89_flip_top_bottom.png 和 frame_89_flip_top_bottom.png
# 已生成增强数据：image_plot_89_translate.png 和 frame_89_translate.png
# 已生成增强数据：image_plot_89_scale.png 和 frame_89_scale.png
# 已生成增强数据：image_plot_89_brightness.png 和 frame_89_brightness.png
# 已生成增强数据：image_plot_89_contrast.png 和 frame_89_contrast.png
# 已生成增强数据：image_plot_89_gaussian_blur.png 和 frame_89_gaussian_blur.png
# 已生成增强数据：image_plot_89_noise.png 和 frame_89_noise.png
# 已生成增强数据：image_plot_89_fixed_crop.png 和 frame_89_fixed_crop.png
# 已生成增强数据：image_plot_9_rotate_90.png 和 frame_9_rotate_90.png
# 已生成增强数据：image_plot_9_rotate_180.png 和 frame_9_rotate_180.png
# 已生成增强数据：image_plot_9_flip_left_right.png 和 frame_9_flip_left_right.png
# 已生成增强数据：image_plot_9_flip_top_bottom.png 和 frame_9_flip_top_bottom.png
# 已生成增强数据：image_plot_9_translate.png 和 frame_9_translate.png
# 已生成增强数据：image_plot_9_scale.png 和 frame_9_scale.png
# 已生成增强数据：image_plot_9_brightness.png 和 frame_9_brightness.png
# 已生成增强数据：image_plot_9_contrast.png 和 frame_9_contrast.png
# 已生成增强数据：image_plot_9_gaussian_blur.png 和 frame_9_gaussian_blur.png
# 已生成增强数据：image_plot_9_noise.png 和 frame_9_noise.png
# 已生成增强数据：image_plot_9_fixed_crop.png 和 frame_9_fixed_crop.png
# 已生成增强数据：image_plot_90_rotate_90.png 和 frame_90_rotate_90.png
# 已生成增强数据：image_plot_90_rotate_180.png 和 frame_90_rotate_180.png
# 已生成增强数据：image_plot_90_flip_left_right.png 和 frame_90_flip_left_right.png
# 已生成增强数据：image_plot_90_flip_top_bottom.png 和 frame_90_flip_top_bottom.png
# 已生成增强数据：image_plot_90_translate.png 和 frame_90_translate.png
# 已生成增强数据：image_plot_90_scale.png 和 frame_90_scale.png
# 已生成增强数据：image_plot_90_brightness.png 和 frame_90_brightness.png
# 已生成增强数据：image_plot_90_contrast.png 和 frame_90_contrast.png
# 已生成增强数据：image_plot_90_gaussian_blur.png 和 frame_90_gaussian_blur.png
# 已生成增强数据：image_plot_90_noise.png 和 frame_90_noise.png
# 已生成增强数据：image_plot_90_fixed_crop.png 和 frame_90_fixed_crop.png
# 已生成增强数据：image_plot_91_rotate_90.png 和 frame_91_rotate_90.png
# 已生成增强数据：image_plot_91_rotate_180.png 和 frame_91_rotate_180.png
# 已生成增强数据：image_plot_91_flip_left_right.png 和 frame_91_flip_left_right.png
# 已生成增强数据：image_plot_91_flip_top_bottom.png 和 frame_91_flip_top_bottom.png
# 已生成增强数据：image_plot_91_translate.png 和 frame_91_translate.png
# 已生成增强数据：image_plot_91_scale.png 和 frame_91_scale.png
# 已生成增强数据：image_plot_91_brightness.png 和 frame_91_brightness.png
# 已生成增强数据：image_plot_91_contrast.png 和 frame_91_contrast.png
# 已生成增强数据：image_plot_91_gaussian_blur.png 和 frame_91_gaussian_blur.png
# 已生成增强数据：image_plot_91_noise.png 和 frame_91_noise.png
# 已生成增强数据：image_plot_91_fixed_crop.png 和 frame_91_fixed_crop.png
# 已生成增强数据：image_plot_92_rotate_90.png 和 frame_92_rotate_90.png
# 已生成增强数据：image_plot_92_rotate_180.png 和 frame_92_rotate_180.png
# 已生成增强数据：image_plot_92_flip_left_right.png 和 frame_92_flip_left_right.png
# 已生成增强数据：image_plot_92_flip_top_bottom.png 和 frame_92_flip_top_bottom.png
# 已生成增强数据：image_plot_92_translate.png 和 frame_92_translate.png
# 已生成增强数据：image_plot_92_scale.png 和 frame_92_scale.png
# 已生成增强数据：image_plot_92_brightness.png 和 frame_92_brightness.png
# 已生成增强数据：image_plot_92_contrast.png 和 frame_92_contrast.png
# 已生成增强数据：image_plot_92_gaussian_blur.png 和 frame_92_gaussian_blur.png
# 已生成增强数据：image_plot_92_noise.png 和 frame_92_noise.png
# 已生成增强数据：image_plot_92_fixed_crop.png 和 frame_92_fixed_crop.png
# 已生成增强数据：image_plot_93_rotate_90.png 和 frame_93_rotate_90.png
# 已生成增强数据：image_plot_93_rotate_180.png 和 frame_93_rotate_180.png
# 已生成增强数据：image_plot_93_flip_left_right.png 和 frame_93_flip_left_right.png
# 已生成增强数据：image_plot_93_flip_top_bottom.png 和 frame_93_flip_top_bottom.png
# 已生成增强数据：image_plot_93_translate.png 和 frame_93_translate.png
# 已生成增强数据：image_plot_93_scale.png 和 frame_93_scale.png
# 已生成增强数据：image_plot_93_brightness.png 和 frame_93_brightness.png
# 已生成增强数据：image_plot_93_contrast.png 和 frame_93_contrast.png
# 已生成增强数据：image_plot_93_gaussian_blur.png 和 frame_93_gaussian_blur.png
# 已生成增强数据：image_plot_93_noise.png 和 frame_93_noise.png
# 已生成增强数据：image_plot_93_fixed_crop.png 和 frame_93_fixed_crop.png
# 已生成增强数据：image_plot_94_rotate_90.png 和 frame_94_rotate_90.png
# 已生成增强数据：image_plot_94_rotate_180.png 和 frame_94_rotate_180.png
# 已生成增强数据：image_plot_94_flip_left_right.png 和 frame_94_flip_left_right.png
# 已生成增强数据：image_plot_94_flip_top_bottom.png 和 frame_94_flip_top_bottom.png
# 已生成增强数据：image_plot_94_translate.png 和 frame_94_translate.png
# 已生成增强数据：image_plot_94_scale.png 和 frame_94_scale.png
# 已生成增强数据：image_plot_94_brightness.png 和 frame_94_brightness.png
# 已生成增强数据：image_plot_94_contrast.png 和 frame_94_contrast.png
# 已生成增强数据：image_plot_94_gaussian_blur.png 和 frame_94_gaussian_blur.png
# 已生成增强数据：image_plot_94_noise.png 和 frame_94_noise.png
# 已生成增强数据：image_plot_94_fixed_crop.png 和 frame_94_fixed_crop.png
# 已生成增强数据：image_plot_95_rotate_90.png 和 frame_95_rotate_90.png
# 已生成增强数据：image_plot_95_rotate_180.png 和 frame_95_rotate_180.png
# 已生成增强数据：image_plot_95_flip_left_right.png 和 frame_95_flip_left_right.png
# 已生成增强数据：image_plot_95_flip_top_bottom.png 和 frame_95_flip_top_bottom.png
# 已生成增强数据：image_plot_95_translate.png 和 frame_95_translate.png
# 已生成增强数据：image_plot_95_scale.png 和 frame_95_scale.png
# 已生成增强数据：image_plot_95_brightness.png 和 frame_95_brightness.png
# 已生成增强数据：image_plot_95_contrast.png 和 frame_95_contrast.png
# 已生成增强数据：image_plot_95_gaussian_blur.png 和 frame_95_gaussian_blur.png
# 已生成增强数据：image_plot_95_noise.png 和 frame_95_noise.png
# 已生成增强数据：image_plot_95_fixed_crop.png 和 frame_95_fixed_crop.png
# 已生成增强数据：image_plot_96_rotate_90.png 和 frame_96_rotate_90.png
# 已生成增强数据：image_plot_96_rotate_180.png 和 frame_96_rotate_180.png
# 已生成增强数据：image_plot_96_flip_left_right.png 和 frame_96_flip_left_right.png
# 已生成增强数据：image_plot_96_flip_top_bottom.png 和 frame_96_flip_top_bottom.png
# 已生成增强数据：image_plot_96_translate.png 和 frame_96_translate.png
# 已生成增强数据：image_plot_96_scale.png 和 frame_96_scale.png
# 已生成增强数据：image_plot_96_brightness.png 和 frame_96_brightness.png
# 已生成增强数据：image_plot_96_contrast.png 和 frame_96_contrast.png
# 已生成增强数据：image_plot_96_gaussian_blur.png 和 frame_96_gaussian_blur.png
# 已生成增强数据：image_plot_96_noise.png 和 frame_96_noise.png
# 已生成增强数据：image_plot_96_fixed_crop.png 和 frame_96_fixed_crop.png
# 已生成增强数据：image_plot_97_rotate_90.png 和 frame_97_rotate_90.png
# 已生成增强数据：image_plot_97_rotate_180.png 和 frame_97_rotate_180.png
# 已生成增强数据：image_plot_97_flip_left_right.png 和 frame_97_flip_left_right.png
# 已生成增强数据：image_plot_97_flip_top_bottom.png 和 frame_97_flip_top_bottom.png
# 已生成增强数据：image_plot_97_translate.png 和 frame_97_translate.png
# 已生成增强数据：image_plot_97_scale.png 和 frame_97_scale.png
# 已生成增强数据：image_plot_97_brightness.png 和 frame_97_brightness.png
# 已生成增强数据：image_plot_97_contrast.png 和 frame_97_contrast.png
# 已生成增强数据：image_plot_97_gaussian_blur.png 和 frame_97_gaussian_blur.png
# 已生成增强数据：image_plot_97_noise.png 和 frame_97_noise.png
# 已生成增强数据：image_plot_97_fixed_crop.png 和 frame_97_fixed_crop.png
# 已生成增强数据：image_plot_98_rotate_90.png 和 frame_98_rotate_90.png
# 已生成增强数据：image_plot_98_rotate_180.png 和 frame_98_rotate_180.png
# 已生成增强数据：image_plot_98_flip_left_right.png 和 frame_98_flip_left_right.png
# 已生成增强数据：image_plot_98_flip_top_bottom.png 和 frame_98_flip_top_bottom.png
# 已生成增强数据：image_plot_98_translate.png 和 frame_98_translate.png
# 已生成增强数据：image_plot_98_scale.png 和 frame_98_scale.png
# 已生成增强数据：image_plot_98_brightness.png 和 frame_98_brightness.png
# 已生成增强数据：image_plot_98_contrast.png 和 frame_98_contrast.png
# 已生成增强数据：image_plot_98_gaussian_blur.png 和 frame_98_gaussian_blur.png
# 已生成增强数据：image_plot_98_noise.png 和 frame_98_noise.png
# 已生成增强数据：image_plot_98_fixed_crop.png 和 frame_98_fixed_crop.png
# 已生成增强数据：image_plot_99_rotate_90.png 和 frame_99_rotate_90.png
# 已生成增强数据：image_plot_99_rotate_180.png 和 frame_99_rotate_180.png
# 已生成增强数据：image_plot_99_flip_left_right.png 和 frame_99_flip_left_right.png
# 已生成增强数据：image_plot_99_flip_top_bottom.png 和 frame_99_flip_top_bottom.png
# 已生成增强数据：image_plot_99_translate.png 和 frame_99_translate.png
# 已生成增强数据：image_plot_99_scale.png 和 frame_99_scale.png
# 已生成增强数据：image_plot_99_brightness.png 和 frame_99_brightness.png
# 已生成增强数据：image_plot_99_contrast.png 和 frame_99_contrast.png
# 已生成增强数据：image_plot_99_gaussian_blur.png 和 frame_99_gaussian_blur.png
# 已生成增强数据：image_plot_99_noise.png 和 frame_99_noise.png
# 已生成增强数据：image_plot_99_fixed_crop.png 和 frame_99_fixed_crop.png
# 数据增强完成，共生成 1705 组增强数据。

# %%
import os
import cv2
import matplotlib.pyplot as plt
import matplotlib.cm as cm

def apply_coolwarm_to_grayscale_images(input_folder, output_folder):
    # Ensure the output directory exists
    os.makedirs(output_folder, exist_ok=True)

    # Loop over all files in the input directory
    for filename in os.listdir(input_folder):
        if filename.endswith(('.png', '.jpg', '.jpeg', '.tiff', '.bmp')):
            # Read the grayscale image
            img_path = os.path.join(input_folder, filename)
            gray_img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            
            # Normalize the image to the range [0, 1] for applying colormap
            norm_img = cv2.normalize(gray_img, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=cv2.CV_32F)
            
            # Apply the coolwarm colormap
            colored_img = cm.coolwarm(norm_img)
            
            # Convert to an RGB image (uint8 format)
            colored_img = (colored_img[:, :, :3] * 255).astype('uint8')

            # Save the new image
            output_path = os.path.join(output_folder, f'coolwarm_{filename}')
            cv2.imwrite(output_path, cv2.cvtColor(colored_img, cv2.COLOR_RGB2BGR))

# Example usage
input_folder = r'D:\Program\d2l\battery\dense_data'
output_folder = r'D:\Program\d2l\battery\dense_data1'
apply_coolwarm_to_grayscale_images(input_folder, output_folder)
